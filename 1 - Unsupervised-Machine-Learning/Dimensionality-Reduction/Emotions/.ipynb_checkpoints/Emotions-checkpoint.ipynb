# %%
import numpy as np
import pandas as pd
import os

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.decomposition import PCA

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

import xgboost as xgb

from matplotlib import image

from PIL import Image

# %%
data = pd.read_csv('src/labels.csv')

# %%
data
# Out:
#        user.id                            image    emotion
# 0          628  facial-expressions_2868588k.jpg      anger
# 1          628  facial-expressions_2868585k.jpg   surprise
# 2          628  facial-expressions_2868584k.jpg    disgust
# 3          628  facial-expressions_2868582k.jpg       fear
# 4        dwdii           Aaron_Eckhart_0001.jpg    neutral
# ...        ...                              ...        ...
# 13685  jhamski            SharmilaTagore_80.jpg  HAPPINESS
# 13686  jhamski            SharmilaTagore_81.jpg  HAPPINESS
# 13687  jhamski            SharmilaTagore_82.jpg  HAPPINESS
# 13688  jhamski            SharmilaTagore_83.jpg  HAPPINESS
# 13689  jhamski             SharmilaTagore_9.jpg  HAPPINESS
#
# [13690 rows x 3 columns]

# %%
data = data.loc[data['image'].apply(lambda image: os.path.isfile(f'src/images/{image}')), :]

# %%
data = data.reset_index(drop=True)
data = data.image

# %%
data
# Out:
# 0        Aaron_Eckhart_0001.jpg
# 1          Aaron_Guiel_0001.jpg
# 2      Aaron_Patterson_0001.jpg
# 3        Aaron_Peirsol_0001.jpg
# 4        Aaron_Peirsol_0002.jpg
#                  ...
# 663        Steve_Waugh_0002.jpg
# 664         Steve_Zahn_0001.jpg
# 665        Stipe_Mesic_0001.jpg
# 666       SharmilaTagore_75.jpg
# 667       SharmilaTagore_79.jpg
# Name: image, Length: 668, dtype: object

# %%
data = np.array(data.values)

# %%
data
# Out:
# array(['Aaron_Eckhart_0001.jpg', 'Aaron_Guiel_0001.jpg',
#        'Aaron_Patterson_0001.jpg', 'Aaron_Peirsol_0001.jpg',
#        'Aaron_Peirsol_0002.jpg', 'Aaron_Peirsol_0003.jpg',
#        'Aaron_Peirsol_0004.jpg', 'Aaron_Pena_0001.jpg',
#        'Aaron_Sorkin_0001.jpg', 'Aaron_Sorkin_0002.jpg',
#        'Aaron_Tippin_0001.jpg', 'Abbas_Kiarostami_0001.jpg',
#        'Abba_Eban_0001.jpg', 'Abdel_Aziz_Al-Hakim_0001.jpg',
#        'Abdel_Madi_Shabneh_0001.jpg', 'Abdel_Nasser_Assidi_0001.jpg',
#        'Abdel_Nasser_Assidi_0002.jpg', 'Abdoulaye_Wade_0001.jpg',
#        'Abdoulaye_Wade_0002.jpg', 'Abdoulaye_Wade_0003.jpg',
#        'Abdoulaye_Wade_0004.jpg', 'Abdulaziz_Kamilov_0001.jpg',
#        'Abdullah_0001.jpg', 'Abdullah_0002.jpg', 'Abdullah_0003.jpg',
#        'Abdullah_0004.jpg', 'Abdullah_Ahmad_Badawi_0001.jpg',
#        'Abdullah_al-Attiyah_0003.jpg', 'Abdullah_Gul_0001.jpg',
#        'Abdullah_Gul_0002.jpg', 'Abdullah_Gul_0003.jpg',
# ...

# %%
new_data = []
for datum in data[:-2]:
    new_data.append(np.asarray(Image.open(f"src/images/{datum}")))

# %%
new_data = np.array(new_data).flatten()

# %%
new_data = np.stack(new_data)

# %%
new_data

# %%
new_data = np.delete(new_data, [-1, -2], axis = 0)

# %%
new_data.shape
