# %% [markdown]
# # Recommendation - Model 🍿

# %% [markdown]
# ---

# %% [markdown]
# <img src="https://visithrastnik.si/uploads/tic/public/generic_list_item/6-kulturna_prireditev_v_avli_kulturnega_centra_zagorje_ob_savi.jpg" />

# %% [markdown]
# ---

# %% [markdown]
# We will train a Machine Learning model based on our previous **ratings** sparse matrix, so that it creates a recommendation engine automatically.

# %% [markdown]
# First, load again the dataframe `movies` and `ratings`

# %%
import os
import pandas as pd
import scipy
import pickle
import lightfm
import numpy as np

from lightfm import LightFM
from lightfm import cross_validation
from lightfm.evaluation import precision_at_k

# %%
### Load the movies and ratings datasets
path = os.path.join("/","home","guillaume","code","GGIML","vivadata-student","data","ml-latest-small")
movies = pd.read_csv(path+os.path.sep+"movies.csv")
ratings = pd.read_csv(path+os.path.sep+"ratings.csv")

# %%
dst_dir = os.path.join("/","home","guillaume","code","GGIML","vivadata-student","data","netflix")

# %%
with open(dst_dir+os.path.sep+'ratings_matrix.pkl', 'rb') as f:
    ratings_matrix = pickle.load(f)

# %%
with open(dst_dir+os.path.sep+'mappers.pkl', 'rb') as f:
    mappers = pickle.load(f)

# %%
idx_to_mid, mid_to_idx, uid_to_idx, idx_to_uid = mappers[0], mappers[1], mappers[2], mappers[3]

# %% [markdown]
# Let's split the data randomly into a `train` matrix and a `test` matrix with 20% of interactions into the test set.

# %%
train_ratings, test_ratings = cross_validation.random_train_test_split(ratings_matrix, test_percentage=.2, random_state=np.random.RandomState(0))

# %% [markdown]
# Let's train a LightFM model for 10 epochs.

# %%
ratings_matrix
# Out:
# <610x9724 sparse matrix of type '<class 'numpy.float64'>'
# 	with 100836 stored elements in Compressed Sparse Row format>

# %% [markdown]
# We use the **WARP** (Weighted Approximate-Rank Pairwise) loss which maximises the rank of positive examples by repeatedly sampling negative examples until rank violating one is found. It is useful when only positive interactions are present and optimising the top of the recommendation list is desired.

# %%
lfm = LightFM(no_components=30, loss='warp')

# %%
lfm.fit(train_ratings, epochs=20)

# %% [markdown]
# Let's evaluate your model on your test set.

# %%
precision_at_k(lfm, test_ratings).mean()
# Out:
# 0.08174342

# %%
lfm.item_embeddings[0]
# Out:
# array([ 0.42676395, -0.3410659 ,  0.15136187, -0.42883462, -0.00804605,
#         0.13135365,  0.3427576 , -0.4339824 , -0.1129528 ,  0.21282552,
#         0.6817652 ,  0.33451477, -0.02379951, -0.12735833,  0.37334958,
#        -0.22396557,  0.3733976 , -0.7290944 ,  0.3329436 ,  0.04068927,
#         0.13342984,  0.29168043,  0.24499665, -0.5547059 , -0.18547276,
#         0.52311647, -0.38751566,  0.18248416,  0.41903153, -0.423558  ],
#       dtype=float32)

# %% [markdown]
# The item_embeddings are features that the model automatically calculated for our movies. It can be used for content-based filtering.

# %% [markdown]
# We just trained a model that factorized our ratings matrix into a U matrix of shape (n_users, no_components) : `model.user_embeddings` ; and V matrix of shape (n_movies, no_components) : `model.item_embeddings`).
#
# Now we want to compute **similarity between each pair of movies**.

# %%
len(lfm.item_embeddings)
# Out:
# 9724

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
#similarity_scores = cosine_similarity(lfm.item_embeddings)
similarity_scores = np.corrcoef(lfm.item_embeddings)

# %%
type(similarity_scores)
# Out:
# numpy.ndarray

# %% [markdown]
# Let's see, for movie of idx 20, the 10 most similar movies?

# %%
most_similar_movies_20 = np.argsort(-similarity_scores[20])

# %% [markdown]
# Let's now test the engine! Suppose we have an user that likes **Toy Story** (movie_id = 1). Which movies would you recommend to that user?

# %%
most_similar_movies_toy_story = np.argsort(-similarity_scores[mid_to_idx[1]])

# %%
toy_story_similar_titles = []
for index in most_similar_movies_toy_story:
    toy_story_similar_titles.append(movies[movies['movieId']==idx_to_mid[index]]['title'].values)

# %%
toy_story_similar_titles[1:6]
# Out:
# [array(['Jurassic Park (1993)'], dtype=object),
#  array(['Mask, The (1994)'], dtype=object),
#  array(['Back to the Future (1985)'], dtype=object),
#  array(['Star Wars: Episode IV - A New Hope (1977)'], dtype=object),
#  array(['Forrest Gump (1994)'], dtype=object)]

# %%
import pickle

# %%
with open(dst_dir+os.path.sep+'similarity_scores.pkl', 'wb') as pklfile:
    pickle.dump(similarity_scores, pklfile)

# %%
movies.to_pickle(dst_dir+os.path.sep+'movies.pkl')

# %%
list_mid = [1,44,592]

sims = []
for mid in list_mid:
    sims.append(similarity_scores[mid_to_idx[mid]])

# %%
len(sims)
# Out:
# 3

# %%
movies.iloc[481]
# Out:
# movieId                                                549
# title      Thirty-Two Short Films About Glenn Gould (1993)
# genres                                       Drama|Musical
# Name: 481, dtype: object

# %%
movies.title[0]
# Out:
# 'Toy Story (1995)'

# %%
def get_sim_scores(list_mid):
    if isinstance(list_mid, int):
        list_mid = [list_mid]
    sims = []
    for mid in list_mid:
        sims.append(similarity_scores[mid_to_idx[mid]])
    return sims

# %%
def get_ranked_recos(sims):
    recos = []
    sum_sims = np.sum(sims, axis = 0)
    most_similar_movies = np.argsort(-sum_sims)
    for index in most_similar_movies:
        recos.append((idx_to_mid[index], sum_sims[index], str(''.join(movies[movies['movieId']==idx_to_mid[index]].title.values))))
    return recos

# %%
get_ranked_recos(get_sim_scores(2))
# Out:
# [(2, 1.0, 'Jumanji (1995)'),
#  (596, 0.97948056, 'Pinocchio (1940)'),
#  (367, 0.94778603, 'Mask, The (1994)'),
#  (10, 0.94637084, 'GoldenEye (1995)'),
#  (653, 0.94063276, 'Dragonheart (1996)'),
#  (780, 0.93556273, 'Independence Day (a.k.a. ID4) (1996)'),
#  (784, 0.9345796, 'Cable Guy, The (1996)'),
#  (588, 0.9333846, 'Aladdin (1992)'),
#  (303, 0.9331948, 'Quick and the Dead, The (1995)'),
#  (788, 0.92988724, 'Nutty Professor, The (1996)'),
#  (48, 0.92257595, 'Pocahontas (1995)'),
#  (586, 0.92141026, 'Home Alone (1990)'),
#  (364, 0.91876686, 'Lion King, The (1994)'),
#  (165, 0.9153266, 'Die Hard: With a Vengeance (1995)'),
#  (6593, 0.907245, 'Freaky Friday (2003)'),
#  (19, 0.9068981, 'Ace Ventura: When Nature Calls (1995)'),
#  (377, 0.90664357, 'Speed (1994)'),
#  (1073, 0.90595484, 'Willy Wonka & the Chocolate Factory (1971)'),
#  (428, 0.90422696, 'Bronx Tale, A (1993)'),
#  (595, 0.89932984, 'Beauty and the Beast (1991)'),
#  (500, 0.896887, 'Mrs. Doubtfire (1993)'),
#  (344, 0.8936827, 'Ace Ventura: Pet Detective (1994)'),
#  (736, 0.8925845, 'Twister (1996)'),
#  (410, 0.8901732, 'Addams Family Values (1993)'),
#  (592, 0.8876176, 'Batman (1989)'),
#  (520, 0.88591105, 'Robin Hood: Men in Tights (1993)'),
#  (104, 0.88548124, 'Happy Gilmore (1996)'),
#  (616, 0.8849351, 'Aristocats, The (1970)'),
#  (2090, 0.8832308, 'Rescuers, The (1977)'),
#  (1027, 0.88306314, 'Robin Hood: Prince of Thieves (1991)'),
#  (216, 0.88288224, 'Billy Madison (1995)'),
#  (145, 0.8819502, 'Bad Boys (1995)'),
#  (519, 0.8817324, 'RoboCop 3 (1993)'),
#  (2002, 0.8813116, 'Lethal Weapon 3 (1992)'),
#  (442, 0.8786489, 'Demolition Man (1993)'),
#  (110, 0.87705076, 'Braveheart (1995)'),
#  (661, 0.87603945, 'James and the Giant Peach (1996)'),
#  (2083, 0.8745263, 'Muppet Christmas Carol, The (1992)'),
#  (6888, 0.8738485, 'Scary Movie 3 (2003)'),
#  (839, 0.87266856, 'Crow: City of Angels, The (1996)'),
#  (673, 0.8724942, 'Space Jam (1996)'),
#  (1831, 0.87244725, 'Lost in Space (1998)'),
#  (761, 0.8691242, 'Phantom, The (1996)'),
#  (3755, 0.8685832, 'Perfect Storm, The (2000)'),
#  (40826, 0.8655639, 'Rent (2005)'),
#  (1918, 0.86531407, 'Lethal Weapon 4 (1998)'),
#  (733, 0.8652848, 'Rock, The (1996)'),
#  (16, 0.8644484, 'Casino (1995)'),
#  (1, 0.86426795, 'Toy Story (1995)'),
#  (1588, 0.8620618, 'George of the Jungle (1997)'),
#  (589, 0.86136675, 'Terminator 2: Judgment Day (1991)'),
#  (34, 0.86122763, 'Babe (1995)'),
#  (380, 0.8603114, 'True Lies (1994)'),
#  (1552, 0.86005586, 'Con Air (1997)'),
#  (253,
#   0.85910136,
#   'Interview with the Vampire: The Vampire Chronicles (1994)'),
#  (208, 0.85609806, 'Waterworld (1995)'),
#  (153, 0.8559844, 'Batman Forever (1995)'),
#  (158, 0.8557228, 'Casper (1995)'),
#  (1515, 0.8554516, 'Volcano (1997)'),
#  (1760, 0.8550705, 'Spice World (1997)'),
#  (3082, 0.8543523, 'World Is Not Enough, The (1999)'),
#  (231, 0.8541581, 'Dumb & Dumber (Dumb and Dumber) (1994)'),
#  (1573, 0.85375935, 'Face/Off (1997)'),
#  (1029, 0.8522417, 'Dumbo (1941)'),
#  (2857, 0.8517104, 'Yellow Submarine (1968)'),
#  (1031, 0.85027885, 'Bedknobs and Broomsticks (1971)'),
#  (480, 0.8493413, 'Jurassic Park (1993)'),
#  (1907, 0.84917986, 'Mulan (1998)'),
#  (786, 0.8482728, 'Eraser (1996)'),
#  (457, 0.84637934, 'Fugitive, The (1993)'),
#  (2096, 0.84454983, 'Sleeping Beauty (1959)'),
#  (3536, 0.8441321, 'Keeping the Faith (2000)'),
#  (2687, 0.84408426, 'Tarzan (1999)'),
#  (40629, 0.843937, 'Pride & Prejudice (2005)'),
#  (30894, 0.8433259, 'White Noise (2005)'),
#  (2501, 0.84302837, 'October Sky (1999)'),
#  (62, 0.8423893, "Mr. Holland's Opus (1995)"),
#  (539, 0.84140337, 'Sleepless in Seattle (1993)'),
#  (370, 0.8413081, 'Naked Gun 33 1/3: The Final Insult (1994)'),
#  (551, 0.83828896, 'Nightmare Before Christmas, The (1993)'),
#  (2087, 0.8353437, 'Peter Pan (1953)'),
#  (420, 0.8352446, 'Beverly Hills Cop III (1994)'),
#  (527, 0.83509797, "Schindler's List (1993)"),
#  (6287, 0.83468884, 'Anger Management (2003)'),
#  (316, 0.8331497, 'Stargate (1994)'),
#  (44, 0.8324294, 'Mortal Kombat (1995)'),
#  (4084, 0.8324084, 'Beverly Hills Cop II (1987)'),
#  (597, 0.83063364, 'Pretty Woman (1990)'),
#  (1917, 0.8298205, 'Armageddon (1998)'),
#  (32029, 0.8296678, 'Hostage (2005)'),
#  (2694, 0.8289141, 'Big Daddy (1999)'),
#  (318, 0.82826704, 'Shawshank Redemption, The (1994)'),
#  (163, 0.8274495, 'Desperado (1995)'),
#  (546, 0.8269034, 'Super Mario Bros. (1993)'),
#  (45431, 0.82571167, 'Over the Hedge (2006)'),
#  (5444, 0.8253592, 'Lilo & Stitch (2002)'),
#  (7454, 0.8248203, 'Van Helsing (2004)'),
#  (587, 0.8244596, 'Ghost (1990)'),
#  (296, 0.8228052, 'Pulp Fiction (1994)'),
#  (594, 0.82264394, 'Snow White and the Seven Dwarfs (1937)'),
#  (2080, 0.82240707, 'Lady and the Tramp (1955)'),
#  (1032, 0.82207286, 'Alice in Wonderland (1951)'),
#  (374, 0.82123864, 'Richie Rich (1994)'),
#  (2617, 0.82069796, 'Mummy, The (1999)'),
#  (4025, 0.81990814, 'Miss Congeniality (2000)'),
#  (2722, 0.81873786, 'Deep Blue Sea (1999)'),
#  (2153, 0.8183786, 'Avengers, The (1998)'),
#  (1407, 0.8182627, 'Scream (1996)'),
#  (2394, 0.81820613, 'Prince of Egypt, The (1998)'),
#  (1544, 0.8176907, 'Lost World: Jurassic Park, The (1997)'),
#  (5957, 0.81659883, 'Two Weeks Notice (2002)'),
#  (3146, 0.8161096, 'Deuce Bigalow: Male Gigolo (1999)'),
#  (1302, 0.81569207, 'Field of Dreams (1989)'),
#  (356, 0.8143273, 'Forrest Gump (1994)'),
#  (186, 0.81422025, 'Nine Months (1995)'),
#  (832, 0.8141187, 'Ransom (1996)'),
#  (1012, 0.81328565, 'Old Yeller (1957)'),
#  (1876, 0.812909, 'Deep Impact (1998)'),
#  (1022, 0.8127066, 'Cinderella (1950)'),
#  (36535, 0.8114152, 'Everything Is Illuminated (2005)'),
#  (1035, 0.81023735, 'Sound of Music, The (1965)'),
#  (150, 0.8095611, 'Apollo 13 (1995)'),
#  (3534, 0.80801153, '28 Days (2000)'),
#  (239, 0.80749637, 'Goofy Movie, A (1995)'),
#  (47, 0.807347, 'Seven (a.k.a. Se7en) (1995)'),
#  (2717, 0.8064077, 'Ghostbusters II (1989)'),
#  (466, 0.80594003, 'Hot Shots! Part Deux (1993)'),
#  (4545, 0.8054754, 'Short Circuit (1986)'),
#  (44709, 0.80517846, 'Akeelah and the Bee (2006)'),
#  (160, 0.804003, 'Congo (1995)'),
#  (4874, 0.80366623, 'K-PAX (2001)'),
#  (1485, 0.8023555, 'Liar Liar (1997)'),
#  (2052, 0.802288, 'Hocus Pocus (1993)'),
#  (3999, 0.8014682, 'Vertical Limit (2000)'),
#  (5630, 0.8009181, 'Red Dragon (2002)'),
#  (5803, 0.8008437, 'I Spy (2002)'),
#  (2004, 0.80040973, 'Gremlins 2: The New Batch (1990)'),
#  (317, 0.798509, 'Santa Clause, The (1994)'),
#  (4148, 0.7981124, 'Hannibal (2001)'),
#  (185, 0.7976602, 'Net, The (1995)'),
#  (353, 0.7971954, 'Crow, The (1994)'),
#  (46965, 0.79691494, 'Snakes on a Plane (2006)'),
#  (260, 0.7965174, 'Star Wars: Episode IV - A New Hope (1977)'),
#  (783, 0.79553694, 'Hunchback of Notre Dame, The (1996)'),
#  (52287, 0.79508096, 'Meet the Robinsons (2007)'),
#  (3114, 0.79486585, 'Toy Story 2 (1999)'),
#  (3256, 0.7944441, 'Patriot Games (1992)'),
#  (802, 0.7935403, 'Phenomenon (1996)'),
#  (3156, 0.79280794, 'Bicentennial Man (1999)'),
#  (5478, 0.79207003, 'Eight Legged Freaks (2002)'),
#  (60126, 0.79181576, 'Get Smart (2008)'),
#  (2005, 0.7915462, 'Goonies, The (1985)'),
#  (2735, 0.7911825, 'Golden Child, The (1986)'),
#  (1499, 0.79095244, 'Anaconda (1997)'),
#  (2355, 0.79055446, "Bug's Life, A (1998)"),
#  (173, 0.7903129, 'Judge Dredd (1995)'),
#  (1967, 0.78985596, 'Labyrinth (1986)'),
#  (361, 0.7897029, 'It Could Happen to You (1994)'),
#  (4220, 0.78869295, 'Longest Yard, The (1974)'),
#  (355, 0.7881591, 'Flintstones, The (1994)'),
#  (719, 0.7881477, 'Multiplicity (1996)'),
#  (66934, 0.78808683, "Dr. Horrible's Sing-Along Blog (2008)"),
#  (393, 0.78801656, 'Street Fighter (1994)'),
#  (339, 0.7879646, 'While You Were Sleeping (1995)'),
#  (3273, 0.7870708, 'Scream 3 (2000)'),
#  (4638, 0.7854823, 'Jurassic Park III (2001)'),
#  (8636, 0.7852997, 'Spider-Man 2 (2004)'),
#  (837, 0.78480315, 'Matilda (1996)'),
#  (5378, 0.7846896, 'Star Wars: Episode II - Attack of the Clones (2002)'),
#  (6565, 0.7846781, 'Seabiscuit (2003)'),
#  (95, 0.7843575, 'Broken Arrow (1996)'),
#  (5481, 0.783672, 'Austin Powers in Goldmember (2002)'),
#  (2581, 0.7834742, 'Never Been Kissed (1999)'),
#  (6, 0.78338015, 'Heat (1995)'),
#  (3247, 0.7833471, 'Sister Act (1992)'),
#  (3824, 0.78297323, 'Autumn in New York (2000)'),
#  (2059, 0.7811502, 'Parent Trap, The (1998)'),
#  (21, 0.7808227, 'Get Shorty (1995)'),
#  (2700, 0.7801515, 'South Park: Bigger, Longer and Uncut (1999)'),
#  (48783, 0.77917504, 'Flags of Our Fathers (2006)'),
#  (1015, 0.7780832, 'Homeward Bound: The Incredible Journey (1993)'),
#  (26614, 0.77804816, 'Bourne Identity, The (1988)'),
#  (1370, 0.77770084, 'Die Hard 2 (1990)'),
#  (7325, 0.777624, 'Starsky & Hutch (2004)'),
#  (338, 0.77760386, 'Virtuosity (1995)'),
#  (8798, 0.77705705, 'Collateral (2004)'),
#  (4369, 0.77642655, 'Fast and the Furious, The (2001)'),
#  (1020, 0.77600235, 'Cool Runnings (1993)'),
#  (4447, 0.7747611, 'Legally Blonde (2001)'),
#  (2081, 0.7744491, 'Little Mermaid, The (1989)'),
#  (4448, 0.77402824, 'Score, The (2001)'),
#  (31225, 0.77392155, 'Coach Carter (2005)'),
#  (32017, 0.7734582, 'Pacifier, The (2005)'),
#  (6958, 0.77249455, 'Haunted Mansion, The (2003)'),
#  (3754, 0.7724002, 'Adventures of Rocky and Bullwinkle, The (2000)'),
#  (1064, 0.7718404, 'Aladdin and the King of Thieves (1996)'),
#  (3, 0.76952606, 'Grumpier Old Men (1995)'),
#  (30825, 0.76917183, 'Meet the Fockers (2004)'),
#  (1438, 0.7689584, "Dante's Peak (1997)"),
#  (3717, 0.7682441, 'Gone in 60 Seconds (2000)'),
#  (1566, 0.7679788, 'Hercules (1997)'),
#  (36708,
#   0.76786244,
#   'Family Guy Presents Stewie Griffin: The Untold Story (2005)'),
#  (1488, 0.7672074, "Devil's Own, The (1997)"),
#  (2001, 0.7667205, 'Lethal Weapon 2 (1989)'),
#  (4623, 0.7664619, 'Major League (1989)'),
#  (2953, 0.7657241, 'Home Alone 2: Lost in New York (1992)'),
#  (67408, 0.7654792, 'Monsters vs. Aliens (2009)'),
#  (593, 0.7651149, 'Silence of the Lambs, The (1991)'),
#  (7324, 0.76504177, 'Hidalgo (2004)'),
#  (1367, 0.76477075, '101 Dalmatians (1996)'),
#  (1777, 0.76365256, 'Wedding Singer, The (1998)'),
#  (368, 0.7636426, 'Maverick (1994)'),
#  (3555, 0.7632721, 'U-571 (2000)'),
#  (531, 0.76320386, 'Secret Garden, The (1993)'),
#  (555, 0.76278186, 'True Romance (1993)'),
#  (1393, 0.76260185, 'Jerry Maguire (1996)'),
#  (671, 0.76253325, 'Mystery Science Theater 3000: The Movie (1996)'),
#  (4679, 0.7615962, 'Uncle Buck (1989)'),
#  (247, 0.76154816, 'Heavenly Creatures (1994)'),
#  (2987, 0.7609617, 'Who Framed Roger Rabbit? (1988)'),
#  (3751, 0.76023495, 'Chicken Run (2000)'),
#  (590, 0.7601427, 'Dances with Wolves (1990)'),
#  (2863, 0.7591842, "Hard Day's Night, A (1964)"),
#  (8360, 0.7589303, 'Shrek 2 (2004)'),
#  (6212, 0.75890565, 'Bringing Down the House (2003)'),
#  (4366, 0.7586874, 'Atlantis: The Lost Empire (2001)'),
#  (7254, 0.75815034, 'The Butterfly Effect (2004)'),
#  (1608, 0.7577111, 'Air Force One (1997)'),
#  (22, 0.7568252, 'Copycat (1995)'),
#  (1556, 0.7567475, 'Speed 2: Cruise Control (1997)'),
#  (1527, 0.7564908, 'Fifth Element, The (1997)'),
#  (3616, 0.75648606, 'Loser (2000)'),
#  (1889, 0.7564626, 'Insomnia (1997)'),
#  (435, 0.7551723, 'Coneheads (1993)'),
#  (2054, 0.755165, 'Honey, I Shrunk the Kids (1989)'),
#  (2888, 0.7550771, 'Drive Me Crazy (1999)'),
#  (648, 0.75480175, 'Mission: Impossible (1996)'),
#  (31, 0.75463176, 'Dangerous Minds (1995)'),
#  (1584, 0.7545031, 'Contact (1997)'),
#  (6754, 0.75441206, 'Underworld (2003)'),
#  (1101, 0.7538344, 'Top Gun (1986)'),
#  (1517, 0.75351113, 'Austin Powers: International Man of Mystery (1997)'),
#  (1010, 0.75344175, 'Love Bug, The (1969)'),
#  (7150, 0.7527219, 'Stuck on You (2003)'),
#  (6957, 0.75243986, 'Bad Santa (2003)'),
#  (1061, 0.7521138, 'Sleepers (1996)'),
#  (6863, 0.75197107, 'School of Rock (2003)'),
#  (333, 0.7509263, 'Tommy Boy (1995)'),
#  (3697, 0.7504156, 'Predator 2 (1990)'),
#  (3159, 0.75013226, 'Fantasia 2000 (1999)'),
#  (2161, 0.74956673, 'NeverEnding Story, The (1984)'),
#  (1792, 0.7493018, 'U.S. Marshals (1998)'),
#  (1282, 0.74905866, 'Fantasia (1940)'),
#  (37727, 0.74904394, 'Flightplan (2005)'),
#  (4816, 0.7489013, 'Zoolander (2001)'),
#  (1196, 0.7487292, 'Star Wars: Episode V - The Empire Strikes Back (1980)'),
#  (62999, 0.74843335, 'Madagascar: Escape 2 Africa (2008)'),
#  (256, 0.7482924, 'Junior (1994)'),
#  (5380, 0.74722135, 'Importance of Being Earnest, The (2002)'),
#  (2353, 0.74704957, 'Enemy of the State (1998)'),
#  (533, 0.7468905, 'Shadow, The (1994)'),
#  (3489, 0.7460868, 'Hook (1991)'),
#  (918, 0.7458388, 'Meet Me in St. Louis (1944)'),
#  (7004, 0.74580735, 'Kindergarten Cop (1990)'),
#  (2011, 0.74516606, 'Back to the Future Part II (1989)'),
#  (2085, 0.7450789, '101 Dalmatians (One Hundred and One Dalmatians) (1961)'),
#  (2294, 0.7428943, 'Antz (1998)'),
#  (39, 0.74263835, 'Clueless (1995)'),
#  (5872, 0.74206394, 'Die Another Day (2002)'),
#  (1037, 0.7414499, 'Lawnmower Man, The (1992)'),
#  (2763, 0.7414422, 'Thomas Crown Affair, The (1999)'),
#  (5171, 0.74140376, 'Time Machine, The (2002)'),
#  (8810, 0.7413011, 'AVP: Alien vs. Predator (2004)'),
#  (2018, 0.74094886, 'Bambi (1942)'),
#  (2683, 0.7402784, 'Austin Powers: The Spy Who Shagged Me (1999)'),
#  (1307, 0.7400587, 'When Harry Met Sally... (1989)'),
#  (49649, 0.7398288, 'Eragon (2006)'),
#  (4896,
#   0.73949975,
#   "Harry Potter and the Sorcerer's Stone (a.k.a. Harry Potter and the Philosopher's Stone) (2001)"),
#  (2701, 0.73949564, 'Wild Wild West (1999)'),
#  (292, 0.7393632, 'Outbreak (1995)'),
#  (799, 0.739159, 'Frighteners, The (1996)'),
#  (4963, 0.73859197, "Ocean's Eleven (2001)"),
#  (4886, 0.73812693, 'Monsters, Inc. (2001)'),
#  (5500, 0.73800296, 'Top Secret! (1984)'),
#  (1356, 0.7378267, 'Star Trek: First Contact (1996)'),
#  (43871, 0.73776037, 'Firewall (2006)'),
#  (1895, 0.73746425, "Can't Hardly Wait (1998)"),
#  (1690, 0.7371738, 'Alien: Resurrection (1997)'),
#  (3175, 0.7365489, 'Galaxy Quest (1999)'),
#  (508, 0.7365189, 'Philadelphia (1993)'),
#  (6548, 0.735416, 'Bad Boys II (2003)'),
#  (2078, 0.7349542, 'Jungle Book, The (1967)'),
#  (3257, 0.7349421, 'Bodyguard, The (1992)'),
#  (2291, 0.73486114, 'Edward Scissorhands (1990)'),
#  (1036, 0.7347951, 'Die Hard (1988)'),
#  (8947, 0.7346463, 'Grudge, The (2004)'),
#  (3793, 0.734584, 'X-Men (2000)'),
#  (1025, 0.7343297, 'Sword in the Stone, The (1963)'),
#  (4446, 0.73266745, 'Final Fantasy: The Spirits Within (2001)'),
#  (1722, 0.73251563, 'Tomorrow Never Dies (1997)'),
#  (7366, 0.73222184, 'Jersey Girl (2004)'),
#  (33166, 0.73213863, 'Crash (2004)'),
#  (608, 0.73197347, 'Fargo (1996)'),
#  (8528, 0.73069614, 'Dodgeball: A True Underdog Story (2004)'),
#  (1265, 0.73062456, 'Groundhog Day (1993)'),
#  (4571, 0.730293, "Bill & Ted's Excellent Adventure (1989)"),
#  (3988,
#   0.72891724,
#   'How the Grinch Stole Christmas (a.k.a. The Grinch) (2000)'),
#  (419, 0.7286139, 'Beverly Hillbillies, The (1993)'),
#  (141, 0.7283506, 'Birdcage, The (1996)'),
#  (32, 0.7282725, 'Twelve Monkeys (a.k.a. 12 Monkeys) (1995)'),
#  (1198,
#   0.7274065,
#   'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)'),
#  (1028, 0.72727543, 'Mary Poppins (1964)'),
#  (64575, 0.7269652, 'Doubt (2008)'),
#  (64622, 0.7261778, 'Reader, The (2008)'),
#  (45501, 0.72608095, 'Break-Up, The (2006)'),
#  (4016, 0.72596616, "Emperor's New Groove, The (2000)"),
#  (4306, 0.72538376, 'Shrek (2001)'),
#  (880, 0.72501427, 'Island of Dr. Moreau, The (1996)'),
#  (2273, 0.7246371, 'Rush Hour (1998)'),
#  (485, 0.7239311, 'Last Action Hero (1993)'),
#  (5991, 0.7236507, 'Chicago (2002)'),
#  (2806, 0.72339416, 'Teaching Mrs. Tingle (1999)'),
#  (2138, 0.72243756, 'Watership Down (1978)'),
#  (2706, 0.7222652, 'American Pie (1999)'),
#  (3033, 0.72150606, 'Spaceballs (1987)'),
#  (1961, 0.7212587, 'Rain Man (1988)'),
#  (2023, 0.72118485, 'Godfather: Part III, The (1990)'),
#  (1270, 0.7204149, 'Back to the Future (1985)'),
#  (8972, 0.72037894, 'National Treasure (2004)'),
#  (2414, 0.71965986, 'Young Sherlock Holmes (1985)'),
#  (1200, 0.7192137, 'Aliens (1986)'),
#  (6297, 0.7188028, 'Holes (2003)'),
#  (2990, 0.71817374, 'Licence to Kill (1989)'),
#  (223, 0.71729475, 'Clerks (1994)'),
#  (5449, 0.71723044, 'Mr. Deeds (2002)'),
#  (3948, 0.71708935, 'Meet the Parents (2000)'),
#  (3623, 0.7165004, 'Mission: Impossible II (2000)'),
#  (801, 0.71647644, 'Harriet the Spy (1996)'),
#  (4022, 0.71644634, 'Cast Away (2000)'),
#  (1021, 0.7163627, 'Angels in the Outfield (1994)'),
#  (2424, 0.7162363, "You've Got Mail (1998)"),
#  (2012, 0.71559966, 'Back to the Future Part III (1990)'),
#  (53996, 0.7154883, 'Transformers (2007)'),
#  (434, 0.71515465, 'Cliffhanger (1993)'),
#  (6249, 0.7147961, 'Boat Trip (2003)'),
#  (2529, 0.714721, 'Planet of the Apes (1968)'),
#  (8977, 0.7146375, 'Alexander (2004)'),
#  (4161, 0.7142686, 'Mexican, The (2001)'),
#  (514, 0.7142322, 'Ref, The (1994)'),
#  (1721, 0.71353227, 'Titanic (1997)'),
#  (8132, 0.71348774, 'Gladiator (1992)'),
#  (2860, 0.7132477, 'Blue Streak (1999)'),
#  (2491, 0.71321964, 'Simply Irresistible (1999)'),
#  (5349, 0.7131677, 'Spider-Man (2002)'),
#  (1005, 0.71265495, 'D3: The Mighty Ducks (1996)'),
#  (1580, 0.71185565, 'Men in Black (a.k.a. MIB) (1997)'),
#  (4326, 0.7116646, 'Mississippi Burning (1988)'),
#  (3990, 0.71149564, 'Rugrats in Paris: The Movie (2000)'),
#  (7161, 0.71114707, 'Cheaper by the Dozen (2003)'),
#  (3593, 0.71032435, 'Battlefield Earth (2000)'),
#  (5218, 0.7103066, 'Ice Age (2002)'),
#  (41566,
#   0.71005213,
#   'Chronicles of Narnia: The Lion, the Witch and the Wardrobe, The (2005)'),
#  (2140, 0.71005124, 'Dark Crystal, The (1982)'),
#  (1380, 0.70986074, 'Grease (1978)'),
#  (1479, 0.70974284, 'Saint, The (1997)'),
#  (32019, 0.70894855, 'Be Cool (2005)'),
#  (1954, 0.7087521, 'Rocky (1976)'),
#  (8984, 0.7079261, "Ocean's Twelve (2004)"),
#  (180, 0.70691746, 'Mallrats (1995)'),
#  (5400, 0.70612633, 'Sum of All Fears, The (2002)'),
#  (1148, 0.70554423, 'Wallace & Gromit: The Wrong Trousers (1993)'),
#  (36527, 0.70527834, 'Proof (2005)'),
#  (3564, 0.70510864, 'Flintstones in Viva Rock Vegas, The (2000)'),
#  (6322, 0.70488065, 'Confidence (2003)'),
#  (2788,
#   0.7043504,
#   "Monty Python's And Now for Something Completely Different (1971)"),
#  (1375, 0.7032893, 'Star Trek III: The Search for Spock (1984)'),
#  (34162, 0.70276237, 'Wedding Crashers (2005)'),
#  (1223, 0.7023276, 'Grand Day Out with Wallace and Gromit, A (1989)'),
#  (8368, 0.7022605, 'Harry Potter and the Prisoner of Azkaban (2004)'),
#  (552, 0.702107, 'Three Musketeers, The (1993)'),
#  (50, 0.70166266, 'Usual Suspects, The (1995)'),
#  (3994, 0.70074284, 'Unbreakable (2000)'),
#  (3439,
#   0.7004931,
#   'Teenage Mutant Ninja Turtles II: The Secret of the Ooze (1991)'),
#  (919, 0.7003953, 'Wizard of Oz, The (1939)'),
#  (1275, 0.6997905, 'Highlander (1986)'),
#  (5103, 0.69958216, 'Sandlot, The (1993)'),
#  (34150, 0.699371, 'Fantastic Four (2005)'),
#  (7293, 0.6991634, '50 First Dates (2004)'),
#  (745, 0.6990817, 'Wallace & Gromit: A Close Shave (1995)'),
#  (3565, 0.69893146, 'Where the Heart Is (2000)'),
#  (4069, 0.69892555, 'Wedding Planner, The (2001)'),
#  (2000, 0.6984287, 'Lethal Weapon (1987)'),
#  (2409, 0.6974903, 'Rocky II (1979)'),
#  (720, 0.69739264, 'Wallace & Gromit: The Best of Aardman Animation (1996)'),
#  (2028, 0.69728065, 'Saving Private Ryan (1998)'),
#  (33004, 0.6969167, "Hitchhiker's Guide to the Galaxy, The (2005)"),
#  (5784, 0.6966283, 'Ghost Ship (2002)'),
#  (8371, 0.6964176, 'Chronicles of Riddick, The (2004)'),
#  (55830, 0.69637555, 'Be Kind Rewind (2008)'),
#  (886, 0.6961843, 'Bulletproof (1996)'),
#  (1676, 0.69528705, 'Starship Troopers (1997)'),
#  (27706, 0.69486123, "Lemony Snicket's A Series of Unfortunate Events (2004)"),
#  (349, 0.69411045, 'Clear and Present Danger (1994)'),
#  (2033, 0.69404346, 'Black Cauldron, The (1985)'),
#  (6373, 0.69398296, 'Bruce Almighty (2003)'),
#  (2268, 0.6938485, 'Few Good Men, A (1992)'),
#  (4558, 0.69381297, 'Twins (1988)'),
#  (293,
#   0.69361454,
#   'Léon: The Professional (a.k.a. The Professional) (Léon) (1994)'),
#  (4246, 0.69330615, "Bridget Jones's Diary (2001)"),
#  (3438, 0.69319624, 'Teenage Mutant Ninja Turtles (1990)'),
#  (6947, 0.6927502, 'Master and Commander: The Far Side of the World (2003)'),
#  (33615, 0.69263226, 'Madagascar (2005)'),
#  (5785, 0.6922929, 'Jackass: The Movie (2002)'),
#  (842, 0.6919971, 'Tales from the Crypt Presents: Bordello of Blood (1996)'),
#  (5541, 0.6918654, 'Hot Shots! (1991)'),
#  (376, 0.69120204, 'River Wild, The (1994)'),
#  (1017, 0.6911608, 'Swiss Family Robinson (1960)'),
#  (17, 0.6907936, 'Sense and Sensibility (1995)'),
#  (3034, 0.69042784, 'Robin Hood (1973)'),
#  (4128, 0.6903534, 'Lost Boys, The (1987)'),
#  (102445, 0.6890132, 'Star Trek Into Darkness (2013)'),
#  (4254, 0.6888143, 'Crocodile Dundee in Los Angeles (2001)'),
#  (4720, 0.688593, 'Others, The (2001)'),
#  (56941, 0.6876176, 'P.S. I Love You (2007)'),
#  (3809, 0.6875361, 'What About Bob? (1991)'),
#  (41997, 0.68751085, 'Munich (2005)'),
#  (8907, 0.687505, 'Shark Tale (2004)'),
#  (56339, 0.6873972, 'Orphanage, The (Orfanato, El) (2007)'),
#  (1210, 0.6865669, 'Star Wars: Episode VI - Return of the Jedi (1983)'),
#  (1408, 0.68625504, 'Last of the Mohicans, The (1992)'),
#  (2115, 0.68612874, 'Indiana Jones and the Temple of Doom (1984)'),
#  (2746, 0.68604994, 'Little Shop of Horrors (1986)'),
#  (2335, 0.6858103, 'Waterboy, The (1998)'),
#  (50068, 0.68539184, 'Letters from Iwo Jima (2006)'),
#  (33679, 0.68497753, 'Mr. & Mrs. Smith (2005)'),
#  (6377, 0.6841903, 'Finding Nemo (2003)'),
#  (46578, 0.68410224, 'Little Miss Sunshine (2006)'),
#  (1688, 0.6841012, 'Anastasia (1997)'),
#  (798, 0.6840736, 'Daylight (1996)'),
#  (1088, 0.6836586, 'Dirty Dancing (1987)'),
#  (79702, 0.6836099, 'Scott Pilgrim vs. the World (2010)'),
#  (7380, 0.68316245, 'Ella Enchanted (2004)'),
#  (161, 0.6830852, 'Crimson Tide (1995)'),
#  (2006, 0.68099046, 'Mask of Zorro, The (1998)'),
#  (7163, 0.6801251, 'Paycheck (2003)'),
#  (2003, 0.6798952, 'Gremlins (1984)'),
#  (72641, 0.67970824, 'Blind Side, The  (2009)'),
#  (72378, 0.67952067, '2012 (2009)'),
#  (55768, 0.6792775, 'Bee Movie (2007)'),
#  (6536, 0.67872, 'Sinbad: Legend of the Seven Seas (2003)'),
#  (5064, 0.678407, 'The Count of Monte Cristo (2002)'),
#  (8908, 0.6782362, 'Ladder 49 (2004)'),
#  (1320, 0.6780881, 'Alien³ (a.k.a. Alien 3) (1992)'),
#  (5944, 0.6779043, 'Star Trek: Nemesis (2002)'),
#  (3000, 0.6776885, 'Princess Mononoke (Mononoke-hime) (1997)'),
#  (3986, 0.6776045, '6th Day, The (2000)'),
#  (1136, 0.67690134, 'Monty Python and the Holy Grail (1975)'),
#  (5, 0.6767796, 'Father of the Bride Part II (1995)'),
#  (3707, 0.6765726, '9 1/2 Weeks (Nine 1/2 Weeks) (1986)'),
#  (3578, 0.6763371, 'Gladiator (2000)'),
#  (5225, 0.6762599, 'And Your Mother Too (Y tu mamá también) (2001)'),
#  (953, 0.6762584, "It's a Wonderful Life (1946)"),
#  (8781, 0.67615026, 'Manchurian Candidate, The (2004)'),
#  (8983, 0.67591846, 'House of Flying Daggers (Shi mian mai fu) (2004)'),
#  (45517, 0.67569584, 'Cars (2006)'),
#  (51084, 0.67564946, 'Music and Lyrics (2007)'),
#  (1183, 0.67516553, 'English Patient, The (1996)'),
#  (5502, 0.67470205, 'Signs (2002)'),
#  (2942, 0.6744279, 'Flashdance (1983)'),
#  (1033, 0.6743413, 'Fox and the Hound, The (1981)'),
#  (2124, 0.6742977, 'Addams Family, The (1991)'),
#  (1047, 0.6735361, 'Long Kiss Goodnight, The (1996)'),
#  (37384, 0.67321754, 'Waiting... (2005)'),
#  (50798, 0.6727215, 'Epic Movie (2007)'),
#  (1291, 0.6723497, 'Indiana Jones and the Last Crusade (1989)'),
#  (337, 0.67231977, "What's Eating Gilbert Grape (1993)"),
#  (1772, 0.6711953, 'Blues Brothers 2000 (1998)'),
#  (6534, 0.6693226, 'Hulk (2003)'),
#  (2640, 0.66920143, 'Superman (1978)'),
#  (585, 0.66877735, 'Brady Bunch Movie, The (1995)'),
#  (1848, 0.66874325, 'Borrowers, The (1997)'),
#  (2406, 0.6683228, 'Romancing the Stone (1984)'),
#  (45672, 0.6683168, 'Click (2006)'),
#  (1391, 0.66775376, 'Mars Attacks! (1996)'),
#  (3484, 0.6674796, 'Skulls, The (2000)'),
#  (30793, 0.6671047, 'Charlie and the Chocolate Factory (2005)'),
#  (4014, 0.6666279, 'Chocolat (2000)'),
#  (2916, 0.66654605, 'Total Recall (1990)'),
#  (2470, 0.66601586, 'Crocodile Dundee (1986)'),
#  (37729, 0.6656837, 'Corpse Bride (2005)'),
#  (60, 0.6656317, 'Indian in the Cupboard, The (1995)'),
#  (6367, 0.6655386, 'Down with Love (2003)'),
#  (1955, 0.66540974, 'Kramer vs. Kramer (1979)'),
#  (5009, 0.6653391, 'Ali (2001)'),
#  (2628, 0.6651984, 'Star Wars: Episode I - The Phantom Menace (1999)'),
#  (1197, 0.66507035, 'Princess Bride, The (1987)'),
#  (30812, 0.66469806, 'Aviator, The (2004)'),
#  (36401, 0.6641286, 'Brothers Grimm, The (2005)'),
#  (6378, 0.6630682, 'Italian Job, The (2003)'),
#  (57243, 0.6629892, "Band's Visit, The (Bikur Ha-Tizmoret) (2007)"),
#  (70, 0.6620988, 'From Dusk Till Dawn (1996)'),
#  (30810, 0.66205263, 'Life Aquatic with Steve Zissou, The (2004)'),
#  (2236, 0.6618598, 'Simon Birch (1998)'),
#  (1377, 0.6616585, 'Batman Returns (1992)'),
#  (2340, 0.6610032, 'Meet Joe Black (1998)'),
#  (1246, 0.6608116, 'Dead Poets Society (1989)'),
#  (43560, 0.6606878, 'Nanny McPhee (2005)'),
#  (1262, 0.6601497, 'Great Escape, The (1963)'),
#  (454, 0.65996134, 'Firm, The (1993)'),
#  (4018, 0.6595588, 'What Women Want (2000)'),
#  (7458, 0.659498, 'Troy (2004)'),
#  (379, 0.65931153, 'Timecop (1994)'),
#  (88, 0.6589072, 'Black Sheep (1996)'),
#  (34338, 0.6587566, 'Aristocrats, The (2005)'),
#  (3785, 0.65862584, 'Scary Movie (2000)'),
#  (2412, 0.65812624, 'Rocky V (1990)'),
#  (3052, 0.6578854, 'Dogma (1999)'),
#  (4969, 0.65766203, 'And Then There Were None (1945)'),
#  (2100, 0.6574915, 'Splash (1984)'),
#  (6944, 0.65674007, 'Father of the Bride (1991)'),
#  (4299, 0.6562875, "Knight's Tale, A (2001)"),
#  (3527, 0.6561784, 'Predator (1987)'),
#  (108190, 0.6559487, 'Divergent (2014)'),
#  (5220, 0.65574646, 'Showtime (2002)'),
#  (3863, 0.6556155, 'Cell, The (2000)'),
#  (7046, 0.6555511, 'Witches of Eastwick, The (1987)'),
#  (329, 0.6553845, 'Star Trek: Generations (1994)'),
#  (2013, 0.6546804, 'Poseidon Adventure, The (1972)'),
#  (61240, 0.6544906, 'Let the Right One In (Låt den rätte komma in) (2008)'),
#  (60069, 0.6542764, 'WALL·E (2008)'),
#  (4718, 0.65411836, 'American Pie 2 (2001)'),
#  (3087, 0.6540947, 'Scrooged (1988)'),
#  (55290, 0.6540121, 'Gone Baby Gone (2007)'),
#  (2528, 0.65351385, "Logan's Run (1976)"),
#  (8970, 0.6532406, 'Finding Neverland (2004)'),
#  (1704, 0.65317017, 'Good Will Hunting (1997)'),
#  (1682, 0.65294844, 'Truman Show, The (1998)'),
#  (2995, 0.65217006, 'House on Haunted Hill (1999)'),
#  (6539,
#   0.65183544,
#   'Pirates of the Caribbean: The Curse of the Black Pearl (2003)'),
#  (7259, 0.6517914, 'You Got Served (2004)'),
#  (43936, 0.6517692, '16 Blocks (2006)'),
#  (5414, 0.6516491, 'Bad Company (2002)'),
#  (122, 0.65159386, 'Boomerang (1992)'),
#  (26084, 0.65141094, 'Music Man, The (1962)'),
#  (6166, 0.65133715, 'Dennis the Menace (1993)'),
#  (342, 0.65132093, "Muriel's Wedding (1994)"),
#  (151, 0.65106577, 'Rob Roy (1995)'),
#  (357, 0.6508133, 'Four Weddings and a Funeral (1994)'),
#  (4011, 0.6508078, 'Snatch (2000)'),
#  (3861, 0.6503298, 'Replacements, The (2000)'),
#  (40815, 0.65024614, 'Harry Potter and the Goblet of Fire (2005)'),
#  (8361, 0.6501721, 'Day After Tomorrow, The (2004)'),
#  (8529, 0.6495308, 'Terminal, The (2004)'),
#  (8937, 0.648869, 'Friday Night Lights (2004)'),
#  (2657, 0.6485159, 'Rocky Horror Picture Show, The (1975)'),
#  (6264, 0.6484431, 'Core, The (2003)'),
#  (8961, 0.6480951, 'Incredibles, The (2004)'),
#  (54004, 0.64776224, 'I Now Pronounce You Chuck and Larry (2007)'),
#  (1396, 0.64773166, 'Sneakers (1992)'),
#  (2728, 0.6471019, 'Spartacus (1960)'),
#  (5459, 0.64686954, 'Men in Black II (a.k.a. MIIB) (a.k.a. MIB 2) (2002)'),
#  (5418, 0.6468034, 'Bourne Identity, The (2002)'),
#  (4132, 0.6464587, 'Mannequin (1987)'),
#  (4340, 0.64645016, 'Animal, The (2001)'),
#  (8784, 0.6464473, 'Garden State (2004)'),
#  (5679, 0.646254, 'Ring, The (2002)'),
#  (628, 0.64602995, 'Primal Fear (1996)'),
#  (1023, 0.64563584, 'Winnie the Pooh and the Blustery Day (1968)'),
#  (49274, 0.64520735, 'Happy Feet (2006)'),
#  (952, 0.64453566, 'Around the World in 80 Days (1956)'),
#  (1755, 0.64446265, 'Shooting Fish (1997)'),
#  (3264, 0.64439774, 'Buffy the Vampire Slayer (1992)'),
#  (4010, 0.6439574, "Brewster's Millions (1985)"),
#  (6059, 0.6438632, 'Recruit, The (2003)'),
#  (2713, 0.6438512, 'Lake Placid (1999)'),
#  (59369, 0.6437481, 'Taken (2008)'),
#  (7147, 0.6436083, 'Big Fish (2003)'),
#  (5572, 0.64356536, 'Barbershop (2002)'),
#  (2137, 0.6427782, "Charlotte's Web (1973)"),
#  (33836, 0.64211816, 'Bewitched (2005)'),
#  (2094, 0.6416993, 'Rocketeer, The (1991)'),
#  (41573, 0.641677, 'Family Stone, The (2005)'),
#  (54256, 0.6415568, 'Hot Rod (2007)'),
#  (5293, 0.64151484, 'Changing Lanes (2002)'),
#  (172, 0.64119536, 'Johnny Mnemonic (1995)'),
#  (4002, 0.6411868, 'Planes, Trains & Automobiles (1987)'),
#  (4489, 0.6411599, 'Coming to America (1988)'),
#  (610, 0.6402163, 'Heavy Metal (1981)'),
#  (6294, 0.6392307, 'Bulletproof Monk (2003)'),
#  (1378, 0.63920224, 'Young Guns (1988)'),
#  (3825, 0.6380475, 'Coyote Ugly (2000)'),
#  (236, 0.63786507, 'French Kiss (1995)'),
#  (2709, 0.63773954, 'Muppets From Space (1999)'),
#  (4701, 0.6375974, 'Rush Hour 2 (2001)'),
#  (1390, 0.6373394, 'My Fellow Americans (1996)'),
#  (2082, 0.6373335, 'Mighty Ducks, The (1992)'),
#  (805, 0.637057, 'Time to Kill, A (1996)'),
#  (2762, 0.63696665, 'Sixth Sense, The (1999)'),
#  (8910, 0.6367091, 'I Heart Huckabees (2004)'),
#  (41571, 0.63628274, 'Memoirs of a Geisha (2005)'),
#  (56805, 0.63619643, 'Walk Hard: The Dewey Cox Story (2007)'),
#  (44199, 0.6356828, 'Inside Man (2006)'),
#  (8169, 0.63557154, '*batteries not included (1987)'),
#  (1911, 0.63553584, 'Dr. Dolittle (1998)'),
#  (8464, 0.6348853, 'Super Size Me (2004)'),
#  (1220, 0.634513, 'Blues Brothers, The (1980)'),
#  (429, 0.6338318, 'Cabin Boy (1994)'),
#  (4270, 0.6338308, 'Mummy Returns, The (2001)'),
#  (59615,
#   0.6336409,
#   'Indiana Jones and the Kingdom of the Crystal Skull (2008)'),
#  (27904, 0.63361406, 'Scanner Darkly, A (2006)'),
#  (2384, 0.63360417, 'Babe: Pig in the City (1998)'),
#  (50601, 0.6335298, 'Bridge to Terabithia (2007)'),
#  (810, 0.6332206, 'Kazaam (1996)'),
#  (47999, 0.632919, 'Jesus Camp (2006)'),
#  (52604, 0.632917, 'Fracture (2007)'),
#  (3252, 0.6327695, 'Scent of a Woman (1992)'),
#  (54190, 0.63261336, 'Across the Universe (2007)'),
#  (59501, 0.632562, 'Chronicles of Narnia: Prince Caspian, The (2008)'),
#  (5364, 0.63197327, 'Unfaithful (2002)'),
#  (2560, 0.63142693, 'Ravenous (1999)'),
#  (1687, 0.63138264, 'Jackal, The (1997)'),
#  (2803, 0.6312659, 'Pelican Brief, The (1993)'),
#  (474, 0.6308737, 'In the Line of Fire (1993)'),
#  (273, 0.6307798, "Mary Shelley's Frankenstein (Frankenstein) (1994)"),
#  (778, 0.630246, 'Trainspotting (1996)'),
#  (3105, 0.6300522, 'Awakenings (1990)'),
#  (3753, 0.6297297, 'Patriot, The (2000)'),
#  (1242, 0.6295148, 'Glory (1989)'),
#  (529, 0.6292554, 'Searching for Bobby Fischer (1993)'),
#  (36, 0.6292188, 'Dead Man Walking (1995)'),
#  (7367, 0.62912184, 'Ladykillers, The (2004)'),
#  (3450, 0.62901765, 'Grumpy Old Men (1993)'),
#  (33437, 0.6287004, 'Unleashed (Danny the Dog) (2005)'),
#  (44665, 0.6282774, 'Lucky Number Slevin (2006)'),
#  (1909, 0.6280372, 'X-Files: Fight the Future, The (1998)'),
#  (5388, 0.6279305, 'Insomnia (2002)'),
#  (5152, 0.6276832, 'We Were Soldiers (2002)'),
#  (5582, 0.6276731, 'Captain Ron (1992)'),
#  (5445, 0.62767, 'Minority Report (2002)'),
#  (1240, 0.62750286, 'Terminator, The (1984)'),
#  (2572, 0.6269963, '10 Things I Hate About You (1999)'),
#  (440, 0.62664866, 'Dave (1993)'),
#  (2232, 0.62649274, 'Cube (1997)'),
#  (362, 0.62640864, 'Jungle Book, The (1994)'),
#  (1821, 0.62621295, 'Object of My Affection, The (1998)'),
#  (147380, 0.6261606, 'Doctor Who: The Next Doctor (2008)'),
#  (55276, 0.626022, 'Michael Clayton (2007)'),
#  (4732, 0.6251853, 'Bubble Boy (2001)'),
#  (2580, 0.6250695, 'Go (1999)'),
#  (44761, 0.6243277, 'Brick (2005)'),
#  (27, 0.62410325, 'Now and Then (1995)'),
#  (1994, 0.6239834, 'Poltergeist (1982)'),
#  (69122, 0.6238096, 'Hangover, The (2009)'),
#  (4776, 0.62370026, 'Training Day (2001)'),
#  (914, 0.6236317, 'My Fair Lady (1964)'),
#  (748, 0.6235263, 'Arrival, The (1996)'),
#  (2791, 0.62347203, 'Airplane! (1980)'),
#  (62956, 0.62290263, "Futurama: Bender's Game (2008)"),
#  (5989, 0.6223068, 'Catch Me If You Can (2002)'),
#  (3396, 0.62212056, 'Muppet Movie, The (1979)'),
#  (8865, 0.62181187, 'Sky Captain and the World of Tomorrow (2004)'),
#  (8370, 0.6216651, 'Blind Swordsman: Zatoichi, The (Zatôichi) (2003)'),
#  (2167, 0.6216005, 'Blade (1998)'),
#  (4639, 0.62118834, "America's Sweethearts (2001)"),
#  (2797, 0.62094784, 'Big (1988)'),
#  (6873, 0.6207002, 'Intolerable Cruelty (2003)'),
#  (1863, 0.62032044, 'Major League: Back to the Minors (1998)'),
#  (267, 0.6199172, 'Major Payne (1995)'),
#  (4054, 0.6198224, 'Save the Last Dance (2001)'),
#  (2795, 0.6197419, "National Lampoon's Vacation (1983)"),
#  (3594, 0.6197374, 'Center Stage (2000)'),
#  (45722, 0.61962914, "Pirates of the Caribbean: Dead Man's Chest (2006)"),
#  (8879, 0.6196089, 'Murder on the Orient Express (1974)'),
#  (2699, 0.619427, 'Arachnophobia (1990)'),
#  (1784, 0.61860603, 'As Good as It Gets (1997)'),
#  (1333, 0.61845165, 'Birds, The (1963)'),
#  (2420, 0.6181506, 'Karate Kid, The (1984)'),
#  (1097, 0.6177329, 'E.T. the Extra-Terrestrial (1982)'),
#  (3081, 0.6164078, 'Sleepy Hollow (1999)'),
#  (575, 0.6161102, 'Little Rascals, The (1994)'),
#  (2959, 0.61589175, 'Fight Club (1999)'),
#  (2478, 0.61501676, '¡Three Amigos! (1986)'),
#  (3017, 0.6149695, 'Creepshow 2 (1987)'),
#  (455, 0.6148128, 'Free Willy (1993)'),
#  (69526, 0.6146506, 'Transformers: Revenge of the Fallen (2009)'),
#  (3977, 0.6137069, "Charlie's Angels (2000)"),
#  (8623, 0.61354524, 'Roxanne (1987)'),
#  (2193, 0.6126838, 'Willow (1988)'),
#  (2253, 0.61255527, 'Toys (1992)'),
#  (2471, 0.61234283, 'Crocodile Dundee II (1988)'),
#  (1562, 0.61214787, 'Batman & Robin (1997)'),
#  (96821, 0.611595, 'Perks of Being a Wallflower, The (2012)'),
#  (3686, 0.6113477, 'Flatliners (1990)'),
#  (53894, 0.6109923, 'Sicko (2007)'),
#  (7173, 0.6105877, 'Along Came Polly (2004)'),
#  (6365, 0.6105672, 'Matrix Reloaded, The (2003)'),
#  (37386, 0.6105257, 'Aeon Flux (2005)'),
#  (2716, 0.6102966, 'Ghostbusters (a.k.a. Ghost Busters) (1984)'),
#  (724, 0.61023337, 'Craft, The (1996)'),
#  (288, 0.6096364, 'Natural Born Killers (1994)'),
#  (1042, 0.60948277, 'That Thing You Do! (1996)'),
#  (107, 0.60899186, 'Muppet Treasure Island (1996)'),
#  (8366, 0.6089743, 'Saved! (2004)'),
#  (63992, 0.60888904, 'Twilight (2008)'),
#  (3624, 0.6088024, 'Shanghai Noon (2000)'),
#  (4995, 0.60866994, 'Beautiful Mind, A (2001)'),
#  (300, 0.6083853, 'Quiz Show (1994)'),
#  (45, 0.608186, 'To Die For (1995)'),
#  (737, 0.6081852, 'Barb Wire (1996)'),
#  (5299, 0.6072719, 'My Big Fat Greek Wedding (2002)'),
#  (3916, 0.6071161, 'Remember the Titans (2000)'),
#  (2549, 0.60677177, 'Wing Commander (1999)'),
#  (48780, 0.6061029, 'Prestige, The (2006)'),
#  (924, 0.60555863, '2001: A Space Odyssey (1968)'),
#  (5954, 0.6052453, '25th Hour (2002)'),
#  (6586, 0.6049796, 'American Wedding (American Pie 3) (2003)'),
#  (3699, 0.6044172, 'Starman (1984)'),
#  (493, 0.603948, 'Menace II Society (1993)'),
#  (6157, 0.60394347, 'Daredevil (2003)'),
#  (8814, 0.6038736, 'Without a Paddle (2004)'),
#  (60937, 0.60379535, 'Mummy: Tomb of the Dragon Emperor, The (2008)'),
#  (6595, 0.603666, 'S.W.A.T. (2003)'),
#  (1372, 0.60272443, 'Star Trek VI: The Undiscovered Country (1991)'),
#  (248, 0.6025602, 'Houseguest (1994)'),
#  (1748, 0.60218644, 'Dark City (1998)'),
#  (168, 0.6021728, 'First Knight (1995)'),
#  (64249, 0.60139954, 'Shrek the Halls (2007)'),
#  (3466, 0.6013511, 'Heart and Souls (1993)'),
#  (2053, 0.6011061, 'Honey, I Blew Up the Kid (1992)'),
#  (4974, 0.60098505, 'Not Another Teen Movie (2001)'),
#  (1083, 0.6007959, 'Great Race, The (1965)'),
#  (1258, 0.6004929, 'Shining, The (1980)'),
#  (1387, 0.6003981, 'Jaws (1975)'),
#  (2918, 0.60037214, "Ferris Bueller's Day Off (1986)"),
#  (3967, 0.599974, 'Billy Elliot (2000)'),
#  (1500, 0.59996235, 'Grosse Pointe Blank (1997)'),
#  (3210, 0.5998236, 'Fast Times at Ridgemont High (1982)'),
#  (27839, 0.59981835, 'Ring Two, The (2005)'),
#  (51255, 0.5997104, 'Hot Fuzz (2007)'),
#  (46723, 0.59932464, 'Babel (2006)'),
#  (24, 0.5991812, 'Powder (1995)'),
#  (69, 0.59904844, 'Friday (1995)'),
#  (8957, 0.5985371, 'Saw (2004)'),
#  (6942, 0.5982221, 'Love Actually (2003)'),
#  (87430, 0.59795874, 'Green Lantern (2011)'),
#  (3301, 0.59786797, 'Whole Nine Yards, The (2000)'),
#  (2108, 0.5978379, 'L.A. Story (1991)'),
#  (1405, 0.59752244, 'Beavis and Butt-Head Do America (1996)'),
#  (1653, 0.5970353, 'Gattaca (1997)'),
#  (5945, 0.5967518, 'About Schmidt (2002)'),
#  (2194, 0.59667593, 'Untouchables, The (1987)'),
#  (3253, 0.59624755, "Wayne's World (1992)"),
#  (49961, 0.5960768, 'Notes on a Scandal (2006)'),
#  (6156, 0.596074, 'Shanghai Knights (2003)'),
#  (35957, 0.59606296, 'Red Eye (2005)'),
#  (8644, 0.59599656, 'I, Robot (2004)'),
#  (1968, 0.59519845, 'Breakfast Club, The (1985)'),
#  (694, 0.59509206, 'Substitute, The (1996)'),
#  (1702, 0.5950666, 'Flubber (1997)'),
#  (45499, 0.5948475, 'X-Men: The Last Stand (2006)'),
#  (2490, 0.5940666, 'Payback (1999)'),
#  (1982, 0.5939433, 'Halloween (1978)'),
#  (30707, 0.59381914, 'Million Dollar Baby (2004)'),
#  (106916, 0.5935736, 'American Hustle (2013)'),
#  (6624, 0.5934854, 'Agent Cody Banks (2003)'),
#  (4370, 0.5929777, 'A.I. Artificial Intelligence (2001)'),
#  (27801, 0.59284896, 'Ong-Bak: The Thai Warrior (Ong Bak) (2003)'),
#  (2908, 0.5927028, "Boys Don't Cry (1999)"),
#  (4814, 0.59269387, "Don't Say a Word (2001)"),
#  (3638, 0.59246427, 'Moonraker (1979)'),
#  (2804, 0.5921343, 'Christmas Story, A (1983)'),
#  (2422, 0.59186876, 'Karate Kid, Part III, The (1989)'),
#  (553, 0.59175485, 'Tombstone (1993)'),
#  (2571, 0.59174705, 'Matrix, The (1999)'),
#  (6874, 0.5917288, 'Kill Bill: Vol. 1 (2003)'),
#  (37830, 0.59164554, 'Final Fantasy VII: Advent Children (2004)'),
#  (1339, 0.5910558, "Dracula (Bram Stoker's Dracula) (1992)"),
#  (46970, 0.59083384, 'Talladega Nights: The Ballad of Ricky Bobby (2006)'),
#  (5816, 0.59075445, 'Harry Potter and the Chamber of Secrets (2002)'),
#  (34334, 0.5902056, 'Stealth (2005)'),
#  (4361, 0.5901901, 'Tootsie (1982)'),
#  (41569, 0.58976966, 'King Kong (2005)'),
#  (1247, 0.58968407, 'Graduate, The (1967)'),
#  (6218, 0.5896728, 'Bend It Like Beckham (2002)'),
#  (4643, 0.58939826, 'Planet of the Apes (2001)'),
#  (6708, 0.5892137, 'Matchstick Men (2003)'),
#  (6764, 0.5890589, 'Rundown, The (2003)'),
#  (45210, 0.5887629, 'United 93 (2006)'),
#  (2985, 0.5884512, 'RoboCop (1987)'),
#  (3535, 0.5883725, 'American Psycho (2000)'),
#  (35836, 0.5880285, '40-Year-Old Virgin, The (2005)'),
#  (54001, 0.58801734, 'Harry Potter and the Order of the Phoenix (2007)'),
#  (6281, 0.58788675, 'Phone Booth (2002)'),
#  (6936, 0.58755964, 'Elf (2003)'),
#  (2450, 0.58685684, 'Howard the Duck (1986)'),
#  (7451, 0.58666974, 'Mean Girls (2004)'),
#  (2428, 0.58651286, 'Faculty, The (1998)'),
#  (1610, 0.5863777, 'Hunt for Red October, The (1990)'),
#  (4351, 0.58587563, 'Point Break (1991)'),
#  (858, 0.5858634, 'Godfather, The (1972)'),
#  (3300, 0.58539325, 'Pitch Black (2000)'),
#  (468,
#   0.58534753,
#   'Englishman Who Went Up a Hill But Came Down a Mountain, The (1995)'),
#  (7360, 0.58479786, 'Dawn of the Dead (2004)'),
#  (45442, 0.58475375, 'Poseidon (2006)'),
#  (1201,
#   0.58457863,
#   'Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il) (1966)'),
#  (1009, 0.58439577, 'Escape to Witch Mountain (1975)'),
#  (433, 0.58427936, 'Clean Slate (1994)'),
#  (2997, 0.58419955, 'Being John Malkovich (1999)'),
#  (47518, 0.5841967, 'Accepted (2006)'),
#  (266, 0.58387756, 'Legends of the Fall (1994)'),
#  (4034, 0.5826662, 'Traffic (2000)'),
#  (3608, 0.5826284, "Pee-wee's Big Adventure (1985)"),
#  (101, 0.5824521, 'Bottle Rocket (1996)'),
#  (2643, 0.5823548, 'Superman IV: The Quest for Peace (1987)'),
#  (2093, 0.5819366, 'Return to Oz (1985)'),
#  (81564, 0.5818469, 'Megamind (2010)'),
#  (135, 0.58153784, 'Down Periscope (1996)'),
#  (1343, 0.5814647, 'Cape Fear (1991)'),
#  (543, 0.5813352, 'So I Married an Axe Murderer (1993)'),
#  (5501, 0.5811648, 'Master of Disguise, The (2002)'),
#  (2502, 0.58089876, 'Office Space (1999)'),
#  (4499, 0.58073723, 'Dirty Rotten Scoundrels (1988)'),
#  (5669, 0.5801342, 'Bowling for Columbine (2002)'),
#  (33164, 0.57958335, 'House of Wax (2005)'),
#  (33493, 0.5793452, 'Star Wars: Episode III - Revenge of the Sith (2005)'),
#  (53468, 0.5793001, 'Fido (2006)'),
#  (174, 0.57921064, 'Jury Duty (1995)'),
#  (77364, 0.5785695, 'Losers, The (2010)'),
#  (7153, 0.57842106, 'Lord of the Rings: The Return of the King, The (2003)'),
#  (2671, 0.5776927, 'Notting Hill (1999)'),
#  (6298, 0.5774849, "Malibu's Most Wanted (2003)"),
#  (4958, 0.57741547, 'Behind Enemy Lines (2001)'),
#  (46972, 0.5770092, 'Night at the Museum (2006)'),
#  (7346, 0.5764273, 'Girl Next Door, The (2004)'),
#  (7381, 0.5761218, 'Whole Ten Yards, The (2004)'),
#  (73023, 0.57608557, 'Crazy Heart (2009)'),
#  (4678, 0.575611, 'UHF (1989)'),
#  (2373, 0.5754737, 'Red Sonja (1985)'),
#  (5956, 0.57540023, 'Gangs of New York (2002)'),
#  (8958, 0.5752489, 'Ray (2004)'),
#  (48385,
#   0.5748389,
#   'Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan (2006)'),
#  (37720, 0.57431734, 'Exorcism of Emily Rose, The (2005)'),
#  (54736, 0.5742917, 'Kingdom, The (2007)'),
#  (6753, 0.57393914, 'Secondhand Lions (2003)'),
#  (1616, 0.57348984, 'Peacemaker, The (1997)'),
#  (524, 0.57323, 'Rudy (1993)'),
#  (923, 0.57257193, 'Citizen Kane (1941)'),
#  (62155, 0.5722197, "Nick and Norah's Infinite Playlist (2008)"),
#  (1476, 0.57192695, 'Private Parts (1997)'),
#  (3499, 0.57157147, 'Misery (1990)'),
#  (920, 0.57119787, 'Gone with the Wind (1939)'),
#  (4040, 0.5710144, "Don't Tell Mom the Babysitter's Dead (1991)"),
#  (31696, 0.5705941, 'Constantine (2005)'),
#  (74458, 0.5705853, 'Shutter Island (2010)'),
#  (7444, 0.57036155, '13 Going on 30 (2004)'),
#  (5995, 0.56980526, 'Pianist, The (2002)'),
#  (2724, 0.56936747, 'Runaway Bride (1999)'),
#  (7361, 0.56829625, 'Eternal Sunshine of the Spotless Mind (2004)'),
#  (2248, 0.5682233, 'Say Anything... (1989)'),
#  (5039, 0.5681019, 'Dragonslayer (1981)'),
#  (1518, 0.56779665, 'Breakdown (1997)'),
#  (6338, 0.56776977, 'Daddy Day Care (2003)'),
#  (2088, 0.56770384, 'Popeye (1980)'),
#  (2947, 0.56748915, 'Goldfinger (1964)'),
#  (3386, 0.5670205, 'JFK (1991)'),
#  (1645, 0.5665019, "The Devil's Advocate (1997)"),
#  (8640, 0.5664773, 'King Arthur (2004)'),
#  (106489, 0.5659578, 'Hobbit: The Desolation of Smaug, The (2013)'),
#  (1604, 0.5652568, 'Money Talks (1997)'),
#  (1639, 0.56517035, 'Chasing Amy (1997)'),
#  (54286, 0.5650468, 'Bourne Ultimatum, The (2007)'),
#  (3160, 0.56465334, 'Magnolia (1999)'),
#  (7139, 0.56441045, 'In America (2002)'),
#  (2792, 0.5643223, 'Airplane II: The Sequel (1982)'),
#  (6711, 0.5642515, 'Lost in Translation (2003)'),
#  (34048, 0.5636608, 'War of the Worlds (2005)'),
#  (2034, 0.56342614, 'Black Hole, The (1979)'),
#  (3147, 0.56335866, 'Green Mile, The (1999)'),
#  (7317, 0.5628131, 'EuroTrip (2004)'),
#  (34319, 0.56268865, 'Island, The (2005)'),
#  (58299, 0.561692, 'Horton Hears a Who! (2008)'),
#  (1213, 0.5615016, 'Goodfellas (1990)'),
#  (6537, 0.5614756, 'Terminator 3: Rise of the Machines (2003)'),
#  (8948, 0.56108695, 'Alfie (2004)'),
#  (58105, 0.5604525, 'Spiderwick Chronicles, The (2008)'),
#  (3483, 0.5604068, 'Road to El Dorado, The (2000)'),
#  (5620, 0.56023926, 'Sweet Home Alabama (2002)'),
#  (5419, 0.5596831, 'Scooby-Doo (2002)'),
#  (79293, 0.55959475, 'Salt (2010)'),
#  (52722, 0.5595654, 'Spider-Man 3 (2007)'),
#  (829, 0.55927145, "Joe's Apartment (1996)"),
#  (196, 0.55918205, 'Species (1995)'),
#  (3225, 0.55917567, 'Down to You (2000)'),
#  (5952, 0.55897963, 'Lord of the Rings: The Two Towers, The (2002)'),
#  (6773,
#   0.5588503,
#   'Triplets of Belleville, The (Les triplettes de Belleville) (2003)'),
#  (1321, 0.5586373, 'American Werewolf in London, An (1981)'),
#  (2174, 0.55859834, 'Beetlejuice (1988)'),
#  (3248, 0.55859005, 'Sister Act 2: Back in the Habit (1993)'),
#  (5618, 0.5577179, 'Spirited Away (Sen to Chihiro no kamikakushi) (2001)'),
#  (4280, 0.5575942, 'World According to Garp, The (1982)'),
#  (91529, 0.5574572, 'Dark Knight Rises, The (2012)'),
#  (55267, 0.557457, 'Dan in Real Life (2007)'),
#  (3701, 0.5574342, 'Alien Nation (1988)'),
#  (4344, 0.5564862, 'Swordfish (2001)'),
#  (4700, 0.5562876, 'Princess Diaries, The (2001)'),
#  (4203, 0.5555812, 'Harley Davidson and the Marlboro Man (1991)'),
#  (3882, 0.5552321, 'Bring It On (2000)'),
#  (31427, 0.5551538, 'Hide and Seek (2005)'),
#  (4386, 0.55444247, 'Cats & Dogs (2001)'),
#  (40819, 0.5544418, 'Walk the Line (2005)'),
#  (1620, 0.5541929, 'Kiss the Girls (1997)'),
#  (3004, 0.5541719, 'Bachelor, The (1999)'),
#  (7373, 0.5539468, 'Hellboy (2004)'),
#  (328, 0.5537662, 'Tales from the Crypt Presents: Demon Knight (1995)'),
#  (6707, 0.5534324, 'Cabin Fever (2002)'),
#  (4848, 0.55321676, 'Mulholland Drive (2001)'),
#  (1214, 0.5529438, 'Alien (1979)'),
#  (2871, 0.5529352, 'Deliverance (1972)'),
#  (8917, 0.55272734, 'Team America: World Police (2004)'),
#  (56174, 0.5523794, 'I Am Legend (2007)'),
#  (168252, 0.55233854, 'Logan (2017)'),
#  (20, 0.5521824, 'Money Train (1995)'),
#  (6503, 0.55217767, "Charlie's Angels: Full Throttle (2003)"),
#  (26133, 0.5520176, 'Charlie Brown Christmas, A (1965)'),
#  (6951, 0.55167365, 'Cat in the Hat, The (2003)'),
#  (64983, 0.5515348, 'Valkyrie (2008)'),
#  (34072, 0.551504, "March of the Penguins (Marche de l'empereur, La) (2005)"),
#  (6006, 0.55113226, 'Just Married (2003)'),
#  (46974, 0.5503242, 'World Trade Center (2006)'),
#  (2427, 0.5501083, 'Thin Red Line, The (1998)'),
#  (3270, 0.5499995, 'Cutting Edge, The (1992)'),
#  (27660, 0.54999495, 'Animatrix, The (2003)'),
#  (2077, 0.54997003, 'Journey of Natty Gann, The (1985)'),
#  (432, 0.5499189, "City Slickers II: The Legend of Curly's Gold (1994)"),
#  (79132, 0.5492305, 'Inception (2010)'),
#  (96737, 0.54920447, 'Dredd (2012)'),
#  (8861, 0.54894525, 'Resident Evil: Apocalypse (2004)'),
#  (7285, 0.54889417, 'Thirteen (2003)'),
#  (2950, 0.5483056, 'Blue Lagoon, The (1980)'),
#  (3552, 0.5482994, 'Caddyshack (1980)'),
#  (8376, 0.54827815, 'Napoleon Dynamite (2004)'),
#  (3869, 0.5473785, 'Naked Gun 2 1/2: The Smell of Fear, The (1991)'),
#  (2231, 0.5470763, 'Rounders (1998)'),
#  (2296, 0.54677486, 'Night at the Roxbury, A (1998)'),
#  (1680, 0.5465863, 'Sliding Doors (1998)'),
#  (5479, 0.5463422, 'K-19: The Widowmaker (2002)'),
#  (915, 0.5462478, 'Sabrina (1954)'),
#  (2346, 0.5462477, 'Stepford Wives, The (1975)'),
#  (7438, 0.5461314, 'Kill Bill: Vol. 2 (2004)'),
#  (63131, 0.5459255, 'Role Models (2008)'),
#  (59022, 0.5457489, 'Harold & Kumar Escape from Guantanamo Bay (2008)'),
#  (4867, 0.54509926, 'Riding in Cars with Boys (2001)'),
#  (45668, 0.5450894, 'Lake House, The (2006)'),
#  (3969, 0.5449624, 'Pay It Forward (2000)'),
#  (2123, 0.54471284, 'All Dogs Go to Heaven (1989)'),
#  (7255, 0.5441493, 'Win a Date with Tad Hamilton! (2004)'),
#  (4321, 0.5438764, 'City Slickers (1991)'),
#  (3255, 0.5437072, 'League of Their Own, A (1992)'),
#  (1359, 0.5433874, 'Jingle All the Way (1996)'),
#  (3510, 0.54322475, 'Frequency (2000)'),
#  (3054, 0.5431976, 'Pokémon: The First Movie (1998)'),
#  (7169, 0.5431318, 'Chasing Liberty (2004)'),
#  (1747, 0.54305536, 'Wag the Dog (1997)'),
#  (6299, 0.5429499, 'Winged Migration (Peuple migrateur, Le) (2001)'),
#  (262, 0.5427468, 'Little Princess, A (1995)'),
#  (212, 0.5427252, 'Bushwhacked (1995)'),
#  (8866, 0.54260635, 'Wimbledon (2004)'),
#  (1732, 0.54251415, 'Big Lebowski, The (1998)'),
#  (27788, 0.54235125, 'Jacket, The (2005)'),
#  (4621, 0.5419605, "Look Who's Talking (1989)"),
#  (431, 0.54176366, "Carlito's Way (1993)"),
#  (1188, 0.5416275, 'Strictly Ballroom (1992)'),
#  (4736, 0.5405043, 'Summer Catch (2001)'),
#  (6266, 0.5404151, 'What a Girl Wants (2003)'),
#  (899, 0.54029775, "Singin' in the Rain (1952)"),
#  (6014, 0.54009014, 'National Security (2003)'),
#  (34405, 0.5393432, 'Serenity (2005)'),
#  (56587, 0.5388092, 'Bucket List, The (2007)'),
#  (1923, 0.5386078, "There's Something About Mary (1998)"),
#  (6879, 0.53854734, 'Runaway Jury (2003)'),
#  (3286, 0.5383595, 'Snow Day (2000)'),
#  (63853, 0.53826565, 'Australia (2008)'),
#  (49396, 0.5381991, 'Tenacious D in The Pick of Destiny (2006)'),
#  (762, 0.53797895, 'Striptease (1996)'),
#  (3745, 0.53754383, 'Titan A.E. (2000)'),
#  (4993,
#   0.53740215,
#   'Lord of the Rings: The Fellowship of the Ring, The (2001)'),
#  (44191, 0.53737205, 'V for Vendetta (2006)'),
#  (1257, 0.53684115, 'Better Off Dead... (1985)'),
#  (830, 0.53682655, 'First Wives Club, The (1996)'),
#  (42013, 0.536746, 'Ringer, The (2005)'),
#  (69784, 0.53647554, 'Brüno (Bruno) (2009)'),
#  (84392, 0.53638905, 'Lincoln Lawyer, The (2011)'),
#  (2723, 0.5362598, 'Mystery Men (1999)'),
#  (4207, 0.5361478, 'Navy Seals (1990)'),
#  (56367, 0.53598154, 'Juno (2007)'),
#  (742, 0.53516, 'Thinner (1996)'),
#  (2367, 0.53488547, 'King Kong (1976)'),
#  (4975, 0.53488374, 'Vanilla Sky (2001)'),
#  (49272, 0.5347971, 'Casino Royale (2006)'),
#  (4265, 0.53441393, 'Driven (2001)'),
#  ...]

# %%
def get_sim_scores(list_mid):
    if isinstance(list_mid, int):
        list_mid = [list_mid]
    sims = []
    for mid in list_mid:
        sims.append(similarity_scores[mid_to_idx[mid]])
    return sims

def get_ranked_recos(sims):
    recos = []
    sum_sims = np.sum(sims, axis = 0)
    most_similar_movies = np.argsort(-sum_sims)
    for index in most_similar_movies:
        recos.append((idx_to_mid[index], sum_sims[index], str(''.join(movies[movies['movieId']==idx_to_mid[index]].title.values))))
    return recos

def get_reco(list_mids, N=5, exclude_selection=False):
    if exclude_selection:
        return get_ranked_recos(get_sim_scores(list_mids))[len(list_mids):N+len(list_mids)]
    else:
        return get_ranked_recos(get_sim_scores(list_mids))[:N]

# %%
get_reco(1)
# Out:
# [(1, 1.0000001, 'Toy Story (1995)'),
#  (1035, 0.9784269, 'Sound of Music, The (1965)'),
#  (318, 0.9766954, 'Shawshank Redemption, The (1994)'),
#  (47, 0.9737339, 'Seven (a.k.a. Se7en) (1995)'),
#  (527, 0.9677736, "Schindler's List (1993)")]

# %%
def get_similarity_scores():
    print("Loading model saved as similarity scores")
    with open(os.path.join(dst_dir, 'similarity_scores.pkl'), 'rb') as input:
        similarity_scores = pickle.load(input)#.astype(float)
    return similarity_scores

# %%
sim_score2 = get_similarity_scores()
# Out:
# Loading model saved as similarity scores

# %%
sim_score2[mid_to_idx[3]]
# Out:
# array([ 0.7026446 ,  1.        ,  0.64096839, ..., -0.86666573,
#        -0.88497698, -0.78055759])

# %%
sim_score2
# Out:
# array([[ 1.        ,  0.7026446 ,  0.85925494, ..., -0.70526429,
#         -0.83986228, -0.79124129],
#        [ 0.7026446 ,  1.        ,  0.64096839, ..., -0.86666573,
#         -0.88497698, -0.78055759],
#        [ 0.85925494,  0.64096839,  1.        , ..., -0.65735629,
#         -0.7766206 , -0.70661544],
#        ...,
#        [-0.70526429, -0.86666573, -0.65735629, ...,  1.        ,
#          0.94400759,  0.95151998],
#        [-0.83986228, -0.88497698, -0.7766206 , ...,  0.94400759,
#          1.        ,  0.96592074],
#        [-0.79124129, -0.78055759, -0.70661544, ...,  0.95151998,
#          0.96592074,  1.        ]])

# %%
mid_to_idx[3]
# Out:
# 1

# %%
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9742 rows x 3 columns]

# %%
def get_movies():
    print("Loading movies dataset as pickle and then transforming it to dict")
    with open(os.path.join(dst_dir, 'movies.pkl'), 'rb') as input:
        df_movies = pickle.load(input)
    movies = df_movies[["movieId", "title"]].set_index("movieId")
    movies_dict = movies.to_dict(orient="index")
    return movies_dict

# %%
movies_dict = get_movies()
# Out:
# Loading movies dataset as pickle and then transforming it to dict

# %%
idx_to_mid
# Out:
# {0: 1,
#  1: 3,
#  2: 6,
#  3: 47,
#  4: 50,
#  5: 70,
#  6: 101,
#  7: 110,
#  8: 151,
#  9: 157,
#  10: 163,
#  11: 216,
#  12: 223,
#  13: 231,
#  14: 235,
#  15: 260,
#  16: 296,
#  17: 316,
#  18: 333,
#  19: 349,
#  20: 356,
#  21: 362,
#  22: 367,
#  23: 423,
#  24: 441,
#  25: 457,
#  26: 480,
#  27: 500,
#  28: 527,
#  29: 543,
#  30: 552,
#  31: 553,
#  32: 590,
#  33: 592,
#  34: 593,
#  35: 596,
#  36: 608,
#  37: 648,
#  38: 661,
#  39: 673,
#  40: 733,
#  41: 736,
#  42: 780,
#  43: 804,
#  44: 919,
#  45: 923,
#  46: 940,
#  47: 943,
#  48: 954,
#  49: 1009,
#  50: 1023,
#  51: 1024,
#  52: 1025,
#  53: 1029,
#  54: 1030,
#  55: 1031,
#  56: 1032,
#  57: 1042,
#  58: 1049,
#  59: 1060,
#  60: 1073,
#  61: 1080,
#  62: 1089,
#  63: 1090,
#  64: 1092,
#  65: 1097,
#  66: 1127,
#  67: 1136,
#  68: 1196,
#  69: 1197,
#  70: 1198,
#  71: 1206,
#  72: 1208,
#  73: 1210,
#  74: 1213,
#  75: 1214,
#  76: 1219,
#  77: 1220,
#  78: 1222,
#  79: 1224,
#  80: 1226,
#  81: 1240,
#  82: 1256,
#  83: 1258,
#  84: 1265,
#  85: 1270,
#  86: 1275,
#  87: 1278,
#  88: 1282,
#  89: 1291,
#  90: 1298,
#  91: 1348,
#  92: 1377,
#  93: 1396,
#  94: 1408,
#  95: 1445,
#  96: 1473,
#  97: 1500,
#  98: 1517,
#  99: 1552,
#  100: 1573,
#  101: 1580,
#  102: 1587,
#  103: 1617,
#  104: 1620,
#  105: 1625,
#  106: 1644,
#  107: 1676,
#  108: 1732,
#  109: 1777,
#  110: 1793,
#  111: 1804,
#  112: 1805,
#  113: 1920,
#  114: 1927,
#  115: 1954,
#  116: 1967,
#  117: 2000,
#  118: 2005,
#  119: 2012,
#  120: 2018,
#  121: 2028,
#  122: 2033,
#  123: 2046,
#  124: 2048,
#  125: 2054,
#  126: 2058,
#  127: 2078,
#  128: 2090,
#  129: 2093,
#  130: 2094,
#  131: 2096,
#  132: 2099,
#  133: 2105,
#  134: 2115,
#  135: 2116,
#  136: 2137,
#  137: 2139,
#  138: 2141,
#  139: 2143,
#  140: 2161,
#  141: 2174,
#  142: 2193,
#  143: 2253,
#  144: 2268,
#  145: 2273,
#  146: 2291,
#  147: 2329,
#  148: 2338,
#  149: 2353,
#  150: 2366,
#  151: 2387,
#  152: 2389,
#  153: 2395,
#  154: 2406,
#  155: 2414,
#  156: 2427,
#  157: 2450,
#  158: 2459,
#  159: 2470,
#  160: 2478,
#  161: 2492,
#  162: 2502,
#  163: 2528,
#  164: 2529,
#  165: 2542,
#  166: 2571,
#  167: 2580,
#  168: 2596,
#  169: 2616,
#  170: 2617,
#  171: 2628,
#  172: 2640,
#  173: 2641,
#  174: 2644,
#  175: 2648,
#  176: 2654,
#  177: 2657,
#  178: 2692,
#  179: 2700,
#  180: 2716,
#  181: 2761,
#  182: 2797,
#  183: 2826,
#  184: 2858,
#  185: 2872,
#  186: 2899,
#  187: 2916,
#  188: 2944,
#  189: 2947,
#  190: 2948,
#  191: 2949,
#  192: 2959,
#  193: 2985,
#  194: 2987,
#  195: 2991,
#  196: 2993,
#  197: 2997,
#  198: 3033,
#  199: 3034,
#  200: 3052,
#  201: 3053,
#  202: 3062,
#  203: 3147,
#  204: 3168,
#  205: 3176,
#  206: 3243,
#  207: 3247,
#  208: 3253,
#  209: 3273,
#  210: 3386,
#  211: 3439,
#  212: 3440,
#  213: 3441,
#  214: 3448,
#  215: 3450,
#  216: 3479,
#  217: 3489,
#  218: 3527,
#  219: 3578,
#  220: 3617,
#  221: 3639,
#  222: 3671,
#  223: 3702,
#  224: 3703,
#  225: 3729,
#  226: 3740,
#  227: 3744,
#  228: 3793,
#  229: 3809,
#  230: 4006,
#  231: 5060,
#  232: 318,
#  233: 1704,
#  234: 6874,
#  235: 8798,
#  236: 46970,
#  237: 48516,
#  238: 58559,
#  239: 60756,
#  240: 68157,
#  241: 71535,
#  242: 74458,
#  243: 77455,
#  244: 79132,
#  245: 80489,
#  246: 80906,
#  247: 86345,
#  248: 89774,
#  249: 91529,
#  250: 91658,
#  251: 99114,
#  252: 106782,
#  253: 109487,
#  254: 112552,
#  255: 114060,
#  256: 115713,
#  257: 122882,
#  258: 131724,
#  259: 31,
#  260: 647,
#  261: 688,
#  262: 720,
#  263: 849,
#  264: 914,
#  265: 1093,
#  266: 1124,
#  267: 1263,
#  268: 1272,
#  269: 1302,
#  270: 1371,
#  271: 2080,
#  272: 2288,
#  273: 2424,
#  274: 2851,
#  275: 3024,
#  276: 3210,
#  277: 3949,
#  278: 4518,
#  279: 5048,
#  280: 5181,
#  281: 5746,
#  282: 5764,
#  283: 5919,
#  284: 6238,
#  285: 6835,
#  286: 7899,
#  287: 7991,
#  288: 26409,
#  289: 70946,
#  290: 72378,
#  291: 21,
#  292: 32,
#  293: 45,
#  294: 52,
#  295: 58,
#  296: 106,
#  297: 125,
#  298: 126,
#  299: 162,
#  300: 171,
#  301: 176,
#  302: 190,
#  303: 215,
#  304: 222,
#  305: 232,
#  306: 247,
#  307: 265,
#  308: 319,
#  309: 342,
#  310: 345,
#  311: 348,
#  312: 351,
#  313: 357,
#  314: 368,
#  315: 417,
#  316: 450,
#  317: 475,
#  318: 492,
#  319: 509,
#  320: 538,
#  321: 539,
#  322: 588,
#  323: 595,
#  324: 599,
#  325: 708,
#  326: 759,
#  327: 800,
#  328: 892,
#  329: 898,
#  330: 899,
#  331: 902,
#  332: 904,
#  333: 908,
#  334: 910,
#  335: 912,
#  336: 920,
#  337: 930,
#  338: 937,
#  339: 1046,
#  340: 1057,
#  341: 1077,
#  342: 1079,
#  343: 1084,
#  344: 1086,
#  345: 1094,
#  346: 1103,
#  347: 1179,
#  348: 1183,
#  349: 1188,
#  350: 1199,
#  351: 1203,
#  352: 1211,
#  353: 1225,
#  354: 1250,
#  355: 1259,
#  356: 1266,
#  357: 1279,
#  358: 1283,
#  359: 1288,
#  360: 1304,
#  361: 1391,
#  362: 1449,
#  363: 1466,
#  364: 1597,
#  365: 1641,
#  366: 1719,
#  367: 1733,
#  368: 1734,
#  369: 1834,
#  370: 1860,
#  371: 1883,
#  372: 1885,
#  373: 1892,
#  374: 1895,
#  375: 1907,
#  376: 1914,
#  377: 1916,
#  378: 1923,
#  379: 1947,
#  380: 1966,
#  381: 1968,
#  382: 2019,
#  383: 2076,
#  384: 2109,
#  385: 2145,
#  386: 2150,
#  387: 2186,
#  388: 2203,
#  389: 2204,
#  390: 2282,
#  391: 2324,
#  392: 2336,
#  393: 2351,
#  394: 2359,
#  395: 2390,
#  396: 2467,
#  397: 2583,
#  398: 2599,
#  399: 2683,
#  400: 2712,
#  401: 2762,
#  402: 2763,
#  403: 2770,
#  404: 2791,
#  405: 2843,
#  406: 2874,
#  407: 2921,
#  408: 2926,
#  409: 2973,
#  410: 3044,
#  411: 3060,
#  412: 3079,
#  413: 3083,
#  414: 3160,
#  415: 3175,
#  416: 3204,
#  417: 3255,
#  418: 3317,
#  419: 3358,
#  420: 3365,
#  421: 3408,
#  422: 3481,
#  423: 3508,
#  424: 3538,
#  425: 3591,
#  426: 3788,
#  427: 3851,
#  428: 3897,
#  429: 3911,
#  430: 3967,
#  431: 3996,
#  432: 4002,
#  433: 4014,
#  434: 4020,
#  435: 4021,
#  436: 4027,
#  437: 4029,
#  438: 4033,
#  439: 4034,
#  440: 4074,
#  441: 4121,
#  442: 4144,
#  443: 4166,
#  444: 4226,
#  445: 4239,
#  446: 4246,
#  447: 4252,
#  448: 4260,
#  449: 4273,
#  450: 4308,
#  451: 4347,
#  452: 4381,
#  453: 4641,
#  454: 4741,
#  455: 4765,
#  456: 4881,
#  457: 4896,
#  458: 4902,
#  459: 4967,
#  460: 34,
#  461: 36,
#  462: 39,
#  463: 150,
#  464: 153,
#  465: 253,
#  466: 261,
#  467: 266,
#  468: 290,
#  469: 300,
#  470: 344,
#  471: 364,
#  472: 380,
#  473: 410,
#  474: 474,
#  475: 515,
#  476: 531,
#  477: 534,
#  478: 589,
#  479: 594,
#  480: 597,
#  481: 2,
#  482: 4,
#  483: 5,
#  484: 7,
#  485: 8,
#  486: 10,
#  487: 11,
#  488: 13,
#  489: 15,
#  490: 16,
#  491: 17,
#  492: 19,
#  493: 22,
#  494: 24,
#  495: 25,
#  496: 26,
#  497: 27,
#  498: 41,
#  499: 43,
#  500: 46,
#  501: 54,
#  502: 60,
#  503: 61,
#  504: 62,
#  505: 65,
#  506: 66,
#  507: 76,
#  508: 79,
#  509: 86,
#  510: 87,
#  511: 88,
#  512: 89,
#  513: 92,
#  514: 93,
#  515: 95,
#  516: 100,
#  517: 102,
#  518: 104,
#  519: 105,
#  520: 112,
#  521: 113,
#  522: 135,
#  523: 140,
#  524: 141,
#  525: 145,
#  526: 146,
#  527: 158,
#  528: 159,
#  529: 160,
#  530: 161,
#  531: 165,
#  532: 168,
#  533: 170,
#  534: 174,
#  535: 177,
#  536: 179,
#  537: 180,
#  538: 181,
#  539: 185,
#  540: 186,
#  541: 189,
#  542: 191,
#  543: 195,
#  544: 196,
#  545: 201,
#  546: 204,
#  547: 205,
#  548: 207,
#  549: 208,
#  550: 209,
#  551: 210,
#  552: 212,
#  553: 217,
#  554: 218,
#  555: 219,
#  556: 224,
#  557: 225,
#  558: 230,
#  559: 234,
#  560: 236,
#  561: 237,
#  562: 239,
#  563: 240,
#  564: 243,
#  565: 248,
#  566: 250,
#  567: 251,
#  568: 252,
#  569: 254,
#  570: 256,
#  571: 257,
#  572: 258,
#  573: 262,
#  574: 267,
#  575: 270,
#  576: 271,
#  577: 273,
#  578: 274,
#  579: 276,
#  580: 277,
#  581: 279,
#  582: 281,
#  583: 282,
#  584: 288,
#  585: 289,
#  586: 291,
#  587: 292,
#  588: 293,
#  589: 302,
#  590: 303,
#  591: 304,
#  592: 310,
#  593: 312,
#  594: 313,
#  595: 314,
#  596: 315,
#  597: 317,
#  598: 327,
#  599: 329,
#  600: 330,
#  601: 332,
#  602: 336,
#  603: 337,
#  604: 339,
#  605: 340,
#  606: 343,
#  607: 347,
#  608: 350,
#  609: 352,
#  610: 353,
#  611: 354,
#  612: 355,
#  613: 358,
#  614: 359,
#  615: 360,
#  616: 361,
#  617: 366,
#  618: 370,
#  619: 371,
#  620: 374,
#  621: 377,
#  622: 378,
#  623: 381,
#  624: 382,
#  625: 383,
#  626: 405,
#  627: 412,
#  628: 415,
#  629: 416,
#  630: 419,
#  631: 426,
#  632: 432,
#  633: 434,
#  634: 435,
#  635: 437,
#  636: 440,
#  637: 445,
#  638: 454,
#  639: 455,
#  640: 458,
#  641: 460,
#  642: 466,
#  643: 468,
#  644: 469,
#  645: 472,
#  646: 477,
#  647: 485,
#  648: 489,
#  649: 490,
#  650: 491,
#  651: 493,
#  652: 494,
#  653: 497,
#  654: 502,
#  655: 505,
#  656: 508,
#  657: 510,
#  658: 516,
#  659: 520,
#  660: 524,
#  661: 532,
#  662: 536,
#  663: 537,
#  664: 540,
#  665: 542,
#  666: 546,
#  667: 548,
#  668: 569,
#  669: 575,
#  670: 587,
#  671: 606,
#  672: 609,
#  673: 616,
#  674: 628,
#  675: 631,
#  676: 637,
#  677: 640,
#  678: 662,
#  679: 667,
#  680: 694,
#  681: 697,
#  682: 700,
#  683: 704,
#  684: 709,
#  685: 710,
#  686: 711,
#  687: 719,
#  688: 747,
#  689: 762,
#  690: 765,
#  691: 775,
#  692: 783,
#  693: 795,
#  694: 799,
#  695: 801,
#  696: 802,
#  697: 818,
#  698: 830,
#  699: 835,
#  700: 837,
#  701: 838,
#  702: 839,
#  703: 842,
#  704: 848,
#  705: 852,
#  706: 867,
#  707: 880,
#  708: 881,
#  709: 888,
#  710: 891,
#  711: 979,
#  712: 981,
#  713: 986,
#  714: 991,
#  715: 996,
#  716: 999,
#  717: 1004,
#  718: 1006,
#  719: 1061,
#  720: 1064,
#  721: 1082,
#  722: 750,
#  723: 924,
#  724: 1101,
#  725: 1246,
#  726: 1584,
#  727: 1610,
#  728: 1682,
#  729: 1784,
#  730: 1917,
#  731: 2671,
#  732: 2688,
#  733: 2701,
#  734: 2717,
#  735: 3114,
#  736: 3354,
#  737: 3623,
#  738: 3869,
#  739: 3916,
#  740: 3977,
#  741: 3994,
#  742: 4018,
#  743: 4223,
#  744: 4306,
#  745: 4310,
#  746: 4370,
#  747: 4643,
#  748: 4700,
#  749: 4844,
#  750: 4874,
#  751: 4886,
#  752: 4963,
#  753: 4993,
#  754: 4995,
#  755: 5218,
#  756: 5349,
#  757: 5378,
#  758: 5445,
#  759: 5459,
#  760: 5464,
#  761: 5502,
#  762: 5618,
#  763: 5816,
#  764: 5952,
#  765: 5989,
#  766: 5991,
#  767: 6333,
#  768: 6365,
#  769: 6534,
#  770: 6539,
#  771: 6863,
#  772: 6934,
#  773: 7143,
#  774: 7153,
#  775: 7155,
#  776: 7445,
#  777: 8207,
#  778: 8360,
#  779: 8368,
#  780: 8373,
#  781: 8528,
#  782: 8636,
#  783: 8665,
#  784: 8666,
#  785: 8783,
#  786: 8808,
#  787: 8865,
#  788: 8870,
#  789: 8907,
#  790: 8908,
#  791: 8949,
#  792: 8957,
#  793: 8958,
#  794: 8961,
#  795: 8965,
#  796: 8970,
#  797: 8972,
#  798: 8984,
#  799: 27741,
#  800: 30812,
#  801: 30816,
#  802: 31878,
#  803: 32029,
#  804: 32031,
#  805: 32296,
#  806: 32587,
#  807: 33162,
#  808: 33493,
#  809: 33794,
#  810: 33836,
#  811: 34048,
#  812: 34319,
#  813: 37741,
#  814: 38388,
#  815: 42002,
#  816: 45499,
#  817: 45517,
#  818: 45668,
#  819: 45730,
#  820: 46530,
#  821: 48783,
#  822: 48997,
#  823: 49272,
#  824: 49278,
#  825: 49286,
#  826: 49824,
#  827: 586,
#  828: 187,
#  829: 627,
#  830: 922,
#  831: 1037,
#  832: 1095,
#  833: 1674,
#  834: 1987,
#  835: 2011,
#  836: 2023,
#  837: 2300,
#  838: 2877,
#  839: 2901,
#  840: 3173,
#  841: 3328,
#  842: 3735,
#  843: 4131,
#  844: 4558,
#  845: 5447,
#  846: 5451,
#  847: 5481,
#  848: 5507,
#  849: 5841,
#  850: 5843,
#  851: 5872,
#  852: 5890,
#  853: 5891,
#  854: 5893,
#  855: 5902,
#  856: 5956,
#  857: 5962,
#  858: 5965,
#  859: 5988,
#  860: 6001,
#  861: 6044,
#  862: 1028,
#  863: 1088,
#  864: 1247,
#  865: 1307,
#  866: 3882,
#  867: 4447,
#  868: 5066,
#  869: 5377,
#  870: 5620,
#  871: 5943,
#  872: 5957,
#  873: 6155,
#  874: 6266,
#  875: 6377,
#  876: 6535,
#  877: 6942,
#  878: 7149,
#  879: 7151,
#  880: 7154,
#  881: 7169,
#  882: 7293,
#  883: 7375,
#  884: 7451,
#  885: 7458,
#  886: 8529,
#  887: 8533,
#  888: 8869,
#  889: 8969,
#  890: 30749,
#  891: 31433,
#  892: 31685,
#  893: 33145,
#  894: 33679,
#  895: 40629,
#  896: 40819,
#  897: 41285,
#  898: 47099,
#  899: 51662,
#  900: 51705,
#  901: 51834,
#  902: 54286,
#  903: 56367,
#  904: 56949,
#  905: 58047,
#  906: 59333,
#  907: 59421,
#  908: 60397,
#  909: 60950,
#  910: 61250,
#  911: 63113,
#  912: 63992,
#  913: 64969,
#  914: 66203,
#  915: 68954,
#  916: 69406,
#  917: 69844,
#  918: 70183,
#  919: 70293,
#  920: 71579,
#  921: 72011,
#  922: 72330,
#  923: 72407,
#  924: 72720,
#  925: 72737,
#  926: 72998,
#  927: 73017,
#  928: 74450,
#  929: 77841,
#  930: 78772,
#  931: 79091,
#  932: 80549,
#  933: 81784,
#  934: 81845,
#  935: 81847,
#  936: 82167,
#  937: 82499,
#  938: 84374,
#  939: 86548,
#  940: 87222,
#  941: 88163,
#  942: 88810,
#  943: 91104,
#  944: 92259,
#  945: 94070,
#  946: 95167,
#  947: 95449,
#  948: 95510,
#  949: 95543,
#  950: 96079,
#  951: 97024,
#  952: 97938,
#  953: 98203,
#  954: 103335,
#  955: 103339,
#  956: 104374,
#  957: 105211,
#  958: 106489,
#  959: 106696,
#  960: 107141,
#  961: 109374,
#  962: 109853,
#  963: 112006,
#  964: 113275,
#  965: 113394,
#  966: 119145,
#  967: 129428,
#  968: 136020,
#  969: 137595,
#  970: 140110,
#  971: 44,
#  972: 376,
#  973: 511,
#  974: 529,
#  975: 1100,
#  976: 1358,
#  977: 1370,
#  978: 1385,
#  979: 1438,
#  980: 1518,
#  981: 1586,
#  982: 1604,
#  983: 1608,
#  984: 1616,
#  985: 1687,
#  986: 1693,
#  987: 1721,
#  988: 1840,
#  989: 1882,
#  990: 1918,
#  991: 2002,
#  992: 2027,
#  993: 1357,
#  994: 1405,
#  995: 1876,
#  996: 2072,
#  997: 2100,
#  998: 2421,
#  999: 2485,
#  ...}

# %%
movies_dict[idx_to_mid[3]]['title']
# Out:
# 'Seven (a.k.a. Se7en) (1995)'
