# %% [markdown]
# # Songs Data
#
# ![](https://images.unsplash.com/photo-1511367734837-f2956f0d8020?ixlib=rb-1.2.1&ixid=eyJhcHBfaWQiOjEyMDd9&auto=format&fit=crop&w=994&q=80)

# %% [markdown]
# ### Import the required libraries

# %%
# TODO - Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as skl
import seaborn as sns

# %% [markdown]
# ### Explore the data

# %%
# TODO - Load the data from train.csv
df_train = pd.read_csv('../input/train.csv')

# %%
df_train
# Out:
#       danceability  duration_ms  energy  instrumentalness  key  liveness  \
# 0            0.600       225133   0.535          0.000005    4    0.1620
# 1            0.880       200373   0.728          0.000054   10    0.3370
# 2            0.882       175511   0.503          0.000000   11    0.1080
# 3            0.791       173987   0.619          0.004230    1    0.3510
# 4            0.532       223147   0.616          0.000000   10    0.0928
# ...            ...          ...     ...               ...  ...       ...
# 1662         0.776       116681   0.608          0.000000   10    0.0932
# 1663         0.531       190000   0.854          0.000000   10    0.0773
# 1664         0.688       193321   0.688          0.000000    3    0.0982
# 1665         0.710       230440   0.814          0.000000   10    0.1600
# 1666         0.855       279867   0.787          0.000000    8    0.1940
#
#       loudness  mode  speechiness    tempo  time_signature  valence
# 0       -7.043     1       0.1070   71.912               4    0.269
# 1       -6.939     0       0.2050  160.976               4    0.715
# 2       -6.618     1       0.1790   95.011               4    0.176
# 3       -5.886     1       0.0532  103.989               4    0.371
# 4       -7.074     0       0.0328  101.883               4    0.292
# ...        ...   ...          ...      ...             ...      ...
# 1662    -6.478     0       0.1040  156.025               4    0.402
# 1663    -3.149     1       0.1980   94.419               4    0.456
# 1664    -5.840     1       0.0357  114.011               4    0.451
# 1665    -4.575     1       0.0561  155.020               4    0.714
# 1666    -4.134     0       0.3340   88.003               4    0.702
#
# [1667 rows x 12 columns]

# %%
# TODO - display a pairplot of the data

# %%
sns.pairplot(df_train)

# %% [markdown]
# ### Identify columns which may be used as a target for linear regression

# %% [markdown]
# Which column would you use as a target for a regression? Why?

# %% [markdown]
# As a target for a regression, I would use 'danceability'.

# %%
# TODO - Create an array X containing all the columns without the target and the target y 
X_train = df_train.drop('danceability', axis = 1)
y_train = df_train.danceability

# %%
# TODO - Load the file test.csv in a new dataframe and create arrays X_test and y_test with the same columns as the X and y
df_test = pd.read_csv('../input/test.csv')
X_test = df_test.drop('danceability', axis = 1)
y_test = df_test.danceability

# %%
# TODO - Run the model and score on the test set
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
lr = LinearRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)

# %%
import math
rmse = math.sqrt(mean_squared_error(y_pred, y_test))
rmse
# Out:
# 0.14201806082279247

# %%
df_train.danceability.describe()
# Out:
# count    1667.000000
# mean        0.686566
# std         0.144544
# min         0.176000
# 25%         0.598500
# 50%         0.704000
# 75%         0.791500
# max         0.972000
# Name: danceability, dtype: float64

# %% [markdown]
# ### Single dimension

# %% [markdown]
# Would it have been possible to predict the previous target with less features? which one would have we kept?

# %%
# TODO - Select a single column and a target and create X and y

# %%
# TODO - Run the model and score it

# %%
#TODO - Plot the results
